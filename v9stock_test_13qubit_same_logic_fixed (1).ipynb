# %% [markdown]
# # Quantum Feature Augmentation for Financial Market Prediction - AWS X State Street
# ### YQuantum 2026
#
# | Section | What You'll Learn |
# |---|---|
# | 1. Setup | Environment and imports |
# | 2. Quantum Approach | Quick reference for key quantum ML vocabulary |
# | 3. Data Generation | Generate the simulated regime-switching market data |
# | 4. Classical Baseline | Polynomial feature expansion + Linear Regression — your bar to beat |
# | 5. Quantum Feature Maps | Encode classical data into quantum states using rotation & entangling gates |
# | 6. Hybrid Workflows | Variational circuits as trainable feature transformers |
# | 8. Dimensionality Reduction | Dealing with overfitting after feature augmentation |
# | 9. Evaluation | Compare all approaches with consistent metrics |
# | 10. Real Stock Data | Task 2 of the challenge |
# | 11. Further Reading | Additional quantum feature engineering methods for a broader landscape |
#
# (This notebook aims to be used as a reference for guiding your implementation.)

# %% [markdown]
# ---
# ## 1. Environment Setup
# We use **Amazon Braket SDK** for all quantum circuits. The `LocalSimulator` runs everything on your machine. When you're ready to scale, you can swap in a managed simulator or QPU with a one-line change.
#
# Note: We recommend keeping in consideration the noise and shot-based circuit evaluations, and not be totally reliant on analytically evaluated quantum circuits for your conclusions
#
# Link to Amazon Braket Documentation: [amazon-braket-documentation](https://docs.aws.amazon.com/braket/latest/developerguide/what-is-braket.html)
#
# Amazon Braket Examples GitHub Repository
# [amazon-braket-examples](https://github.com/amazon-braket/amazon-braket-examples)

# %%
# PROVIDED — install dependencies (run once)
# Uncomment the line below if you haven't installed these yet
# On Braket notebook instances, braket-sdk/numpy/matplotlib are pre-installed.
# Use %pip (not !pip) to ensure packages install into the active kernel environment.
# %pip install -q scipy scikit-learn pandas seaborn pennylane
# %pip install amazon-braket-sdk amazon-braket-pennylane-plugin 
# %pip install yfinance
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: amazon-braket-sdk in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (1.114.0)
# Requirement already satisfied: amazon-braket-pennylane-plugin in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (1.34.0)
# Requirement already satisfied: amazon-braket-schemas>=1.27.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (1.29.0)
# Requirement already satisfied: amazon-braket-default-simulator>=1.32.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (1.34.1)
# Requirement already satisfied: oqpy~=0.3.7 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (0.3.10)
# Requirement already satisfied: backoff in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (2.2.1)
# Requirement already satisfied: boltons in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (25.0.0)
# Requirement already satisfied: boto3>=1.28.53 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (1.42.81)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (2.2.1)
# Requirement already satisfied: nest-asyncio in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (1.6.0)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (3.6.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (2.2.6)
# Requirement already satisfied: openpulse in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (1.0.1)
# Requirement already satisfied: openqasm3 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (1.0.1)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (1.14.0)
# Requirement already satisfied: backports.entry-points-selectable in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.2.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from oqpy~=0.3.7->amazon-braket-sdk) (1.1.0)
# Requirement already satisfied: autoray>=0.6.11 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-pennylane-plugin) (0.8.2)
# Requirement already satisfied: pennylane>=0.44.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-pennylane-plugin) (0.44.1)
# Requirement already satisfied: numba in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk) (0.65.0)
# Requirement already satisfied: opt_einsum in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk) (3.4.0)
# Requirement already satisfied: pydantic>2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk) (2.12.5)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk) (1.17.1)
# Requirement already satisfied: setuptools==81.0.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk) (81.0.0)
# Requirement already satisfied: antlr4-python3-runtime==4.13.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk) (4.13.2)
# Requirement already satisfied: botocore<1.43.0,>=1.42.81 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from boto3>=1.28.53->amazon-braket-sdk) (1.42.81)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from boto3>=1.28.53->amazon-braket-sdk) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from boto3>=1.28.53->amazon-braket-sdk) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.81->boto3>=1.28.53->amazon-braket-sdk) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.81->boto3>=1.28.53->amazon-braket-sdk) (2.6.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.81->boto3>=1.28.53->amazon-braket-sdk) (1.17.0)
# Requirement already satisfied: rustworkx>=0.14.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (0.17.1)
# Requirement already satisfied: autograd in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (1.8.0)
# Requirement already satisfied: appdirs in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (1.4.4)
# Requirement already satisfied: cachetools in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (7.0.5)
# Requirement already satisfied: pennylane-lightning>=0.44 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (0.44.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (2.32.5)
# Requirement already satisfied: tomlkit in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (0.14.0)
# Requirement already satisfied: typing_extensions in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (4.15.0)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (25.0)
# Requirement already satisfied: diastatic-malt==2.15.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (2.15.2)
# Requirement already satisfied: gast in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane>=0.44.0->amazon-braket-pennylane-plugin) (0.7.0)
# Requirement already satisfied: astunparse in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from diastatic-malt==2.15.2->pennylane>=0.44.0->amazon-braket-pennylane-plugin) (1.6.3)
# Requirement already satisfied: termcolor in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from diastatic-malt==2.15.2->pennylane>=0.44.0->amazon-braket-pennylane-plugin) (3.3.0)
# Requirement already satisfied: scipy-openblas32>=0.3.26 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane-lightning>=0.44->pennylane>=0.44.0->amazon-braket-pennylane-plugin) (0.3.31.188.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk) (0.4.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from astunparse->diastatic-malt==2.15.2->pennylane>=0.44.0->amazon-braket-pennylane-plugin) (0.46.3)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from numba->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk) (0.47.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from requests->pennylane>=0.44.0->amazon-braket-pennylane-plugin) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from requests->pennylane>=0.44.0->amazon-braket-pennylane-plugin) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from requests->pennylane>=0.44.0->amazon-braket-pennylane-plugin) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from sympy->amazon-braket-sdk) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: yfinance in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (1.2.0)
# Requirement already satisfied: pandas>=1.3.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (2.2.6)
# Requirement already satisfied: requests>=2.31 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (4.9.4)
# Requirement already satisfied: pytz>=2022.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (2026.1.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (4.0.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (7.34.1)
# Requirement already satisfied: websockets>=13.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.2.25)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["AWS_DEFAULT_REGION"] = "us-east-1"
os.environ["AWS_ACCESS_KEY_ID"] = "ASIAUS6RCOD4OF3YN7SE"
os.environ["AWS_SECRET_ACCESS_KEY"] = "0UG4seI2iafp2847c8BdLc3cM5vXh5n2ZIy9w66u"
os.environ["AWS_SESSION_TOKEN"] = "..."  # only if using temporary creds

# %%
import boto3

# Check your account ID
account_id = boto3.client("sts").get_caller_identity()["Account"]
region = boto3.session.Session().region_name
print(f"Account: {account_id}")
print(f"Region: {region}")

# Default Braket bucket name
default_bucket = f"amazon-braket-{region}-{account_id}"
print(f"Default bucket: {default_bucket}")

# Verify it exists
s3 = boto3.client("s3")
try:
    s3.head_bucket(Bucket=default_bucket)
    print("Bucket exists!")
except:
    print("Bucket not found — creating it...")
    s3.create_bucket(Bucket=default_bucket)
# Out:
# Account: 315581690104
# Region: us-east-1
# Default bucket: amazon-braket-us-east-1-315581690104
# Bucket exists!

# %%
# Imports
    
# Core
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Classical Machine Learning
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from scipy.stats import pearsonr

# Quantum Machine Learning
import pennylane as qml
from pennylane import numpy as pnp

# Amazon Braket
from braket.circuits import Circuit, Observable, ResultType
from braket.devices import LocalSimulator

# Reproducibility
np.random.seed(42)

# Local state-vector simulator (exact, no shot noise)
SV_DEVICE = LocalSimulator("default")

# Setting up Amazon Braket Environment

N_QUBITS = 4  # One qubit per feature (X1, X2, X3, X4)

# Local Simulator
dev_braket_local = qml.device(
    "braket.local.qubit",
    wires=N_QUBITS,
    backend="default",  # Braket's local state vector simulator
)


# AWS Quantum Hardware
# dev_braket = qml.device(
#  "braket.aws.qubit",
#   device_arn="arn:aws:braket:us-west-1::device/qpu/rigetti/Ankaa-3",
#   wires=N_QUBITS,
#   s3_destination_folder=(default_bucket, "your-prefix"),
#   shots=1000,
#)
print("INIT SUCCESS")
# Out:
# INIT SUCCESS

# %% [markdown]
# ## 2. Quantum Approach: Quick Reference
#
# Here's the specific vocabulary we'll use throughout:
#
# | Term | Meaning |
# |---|---|
# | **Feature map** | A quantum circuit that encodes a classical data point **x** into a quantum state \|φ(x)⟩. Different circuits create different encodings. |
# | **Hilbert space** | The exponentially large state space of *n* qubits (dimension 2ⁿ). A 10-qubit system lives in a 1024-dimensional space. |
# | **Variational circuit** | A parameterized quantum circuit where gate angles are *learned* during training, like weights in a neural network. |
# | **Expectation value** | Measuring an observable (e.g., Pauli-Z) on a qubit gives a number in [-1, 1]. We use these as features. |
#
# **Why might quantum features help for financial data?**
#
# Financial signals are buried in noise, and the relationships between features can be highly non-linear (e.g., regime-dependent interactions). Quantum feature maps project data into an exponentially large Hilbert space where these non-linear relationships may become linearly separable — similar in spirit to the classical kernel trick, but accessing a fundamentally different class of feature spaces.

# %% [markdown]
# ## 3. Data Generation - Simulated Regime Process
#
# Refer the challenge spec: a two-regime process where Regime 1 (75% of the time) has one set of relationships and Regime 2 (25%) has a different set.

# %%
def generate_regime_data(n_samples, seed=42):
    """
    Generate synthetic regime-switching data per the challenge spec.
    
    Returns:
        X: array of shape (n_samples, 4) — features X1, X2, X3, X4
        y: array of shape (n_samples,) — target variable
        regimes: array of shape (n_samples,) — 0 for Regime 1, 1 for Regime 2
    """
    rng = np.random.default_rng(seed)
    
    # Assign regimes: 75% Regime 1, 25% Regime 2
    regimes = rng.choice([0, 1], size=n_samples, p=[0.75, 0.25])
    
    n1 = np.sum(regimes == 0)
    n2 = np.sum(regimes == 1)
    
    X = np.zeros((n_samples, 4))
    y = np.zeros(n_samples)
    
    # --- Regime 1 ---
    mask1 = regimes == 0
    X[mask1, 0] = rng.standard_normal(n1)          # X1 ~ N(0,1)
    X[mask1, 1] = rng.standard_normal(n1)          # X2 ~ N(0,1)
    X[mask1, 2] = rng.standard_normal(n1)          # X3 ~ N(0,1)
    X[mask1, 3] = rng.uniform(-1, 1, size=n1)     # X4 ~ Uniform(-1,1)
    eps1 = rng.standard_normal(n1)                  # noise
    
    y[mask1] = 2 * X[mask1, 0] - X[mask1, 1] + eps1
    
    # --- Regime 2 ---
    mask2 = regimes == 1
    
    # X1 and X3 are jointly normal with correlation 0.8
    mean = [3, 3]
    cov = [[1, 0.8],
           [0.8, 1]]
    x1_x3 = rng.multivariate_normal(mean, cov, size=n2)
    X[mask2, 0] = x1_x3[:, 0]                      # X1
    X[mask2, 2] = x1_x3[:, 1]                      # X3
    
    # X2 ~ Cauchy(0,1)
    X[mask2, 1] = rng.standard_cauchy(size=n2)
    
    # X4 ~ Exponential(lambda=1)
    X[mask2, 3] = rng.exponential(scale=1.0, size=n2)
    
    eps2 = rng.standard_normal(n2)                  # noise
    
    y[mask2] = (X[mask2, 0] * X[mask2, 2]) + np.log(np.abs(X[mask2, 1]) + 1) + eps2
    
    return X, y, regimes


# Generate train and test sets
X_train, y_train, regimes_train = generate_regime_data(10000, seed=42)
X_test, y_test, regimes_test = generate_regime_data(10000, seed=123)

print(f"Train: X shape {X_train.shape}, y shape {y_train.shape}")
print(f"  Regime 1: {np.sum(regimes_train == 0)}, Regime 2: {np.sum(regimes_train == 1)}")
print(f"Test:  X shape {X_test.shape}, y shape {y_test.shape}")
print(f"  Regime 1: {np.sum(regimes_test == 0)}, Regime 2: {np.sum(regimes_test == 1)}")

# Quick sanity checks
print(f"\nTrain y — mean: {y_train.mean():.3f}, std: {y_train.std():.3f}")
print(f"Test  y — mean: {y_test.mean():.3f}, std: {y_test.std():.3f}")
print(f"\nRegime 2 X2 (Cauchy) — min: {X_train[regimes_train==1, 1].min():.1f}, max: {X_train[regimes_train==1, 1].max():.1f}")
# Out:
# Train: X shape (10000, 4), y shape (10000,)
#   Regime 1: 7558, Regime 2: 2442
# Test:  X shape (10000, 4), y shape (10000,)
#   Regime 1: 7633, Regime 2: 2367
#
# Train y — mean: 2.633, std: 5.948
# Test  y — mean: 2.597, std: 5.840
#
# Regime 2 X2 (Cauchy) — min: -614.6, max: 4488.2

# %%
# Simulated Data Generation
def preprocess_features(X_train, X_test, clip_value=5.0):
    """
    Standardize and clip features for use with quantum circuits.
    
    Quantum rotation gates expect bounded inputs — unbounded values
    (especially from Cauchy-distributed X2) would wrap around and
    destroy meaningful encoding.
    
    Steps:
        1. Standardize (zero mean, unit variance) fit on train only
        2. Clip to [-clip_value, clip_value] to tame Cauchy outliers
        3. Rescale to [0, pi] for rotation gate compatibility
    
    Returns:
        X_train_processed, X_test_processed, scaler
    """
    # Step 1: Standardize (fit on train, transform both)
    scaler = StandardScaler()
    X_train_s = scaler.fit_transform(X_train)
    X_test_s = scaler.transform(X_test)
    
    # Step 2: Clip outliers
    X_train_s = np.clip(X_train_s, -clip_value, clip_value)
    X_test_s = np.clip(X_test_s, -clip_value, clip_value)
    
    # Step 3: Rescale to [0, pi] for quantum rotation gates
    X_train_q = (X_train_s + clip_value) / (2 * clip_value) * np.pi
    X_test_q = (X_test_s + clip_value) / (2 * clip_value) * np.pi
    
    return X_train_s, X_test_s, X_train_q, X_test_q, scaler


X_train_s, X_test_s, X_train_q, X_test_q, scaler = preprocess_features(X_train, X_test)

print("Standardized (for classical models):")
print(f"  Train — min: {X_train_s.min():.2f}, max: {X_train_s.max():.2f}")
print(f"  Test  — min: {X_test_s.min():.2f}, max: {X_test_s.max():.2f}")

print(f"\nQuantum-ready [0, pi]:")
print(f"  Train — min: {X_train_q.min():.4f}, max: {X_train_q.max():.4f}")
print(f"  Test  — min: {X_test_q.min():.4f}, max: {X_test_q.max():.4f}")

# Check how many values got clipped
n_clipped = np.sum(np.abs(X_train_s) == 5.0)
print(f"\nClipped values in train: {n_clipped} ({n_clipped / X_train_s.size * 100:.2f}%)")
# Out:
# Standardized (for classical models):
#   Train — min: -5.00, max: 5.00
#   Test  — min: -5.00, max: 5.00
#
# Quantum-ready [0, pi]:
#   Train — min: 0.0000, max: 3.1416
#   Test  — min: 0.0000, max: 3.1416
#
# Clipped values in train: 34 (0.08%)

# %% [markdown]
# ## 4. Classical Baseline
#
# Before touching any quantum circuit, establish a strong classical baseline. The challenge requires linear regression as the base model. Classically, We augment features with polynomial expansions (degree 2) - this gives the model access to all pairwise interactions (like x₁·x₃).
#
# **Classical baseline is your bar to rigorously compare against**, If quantum features don't improve on this, that's a valid (and publishable) negative result.

# %%
# classical baseline with polynomial features
# This is a simple classical approach, feel free to extend this with classically researched methods for equally elevated comparisons

# NOTE: Example Code
# X_train_s, y_train etc are undefined in the example below

def evaluate_model(y_true, y_pred, label=""):
    """Compute standard regression metrics."""
    mse  = mean_squared_error(y_true, y_pred)
    mae  = mean_absolute_error(y_true, y_pred)
    corr = pearsonr(y_true, y_pred)[0]
    return {"model": label, "MSE": round(mse, 6), "MAE": round(mae, 6), "Corr": round(corr, 4)}


# --- Degree-1 (raw features) ---
lr_raw = LinearRegression().fit(X_train_s, y_train)
pred_raw = lr_raw.predict(X_test_s)
results_feature_maps = [evaluate_model(y_test, pred_raw, "LR (raw features)")]

# --- Degree-2 (polynomial features) ---
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
X_train_poly = poly.fit_transform(X_train_s)
X_test_poly  = poly.transform(X_test_s)

lr_poly = LinearRegression().fit(X_train_poly, y_train)
pred_poly = lr_poly.predict(X_test_poly)
results_feature_maps.append(evaluate_model(y_test, pred_poly, "LR (poly deg=2)"))

# %%
# perform cross-validation to find a good alpha for Ridge regression on the polynomial features
from sklearn.model_selection import GridSearchCV
ridge_cv = GridSearchCV(Ridge(), param_grid={"alpha": [0.01, 0.1, 1.0, 10.0]}, cv=5)
ridge_cv.fit(X_train_poly, y_train)
print(f"Best alpha for Ridge (poly features): {ridge_cv.best_params_['alpha']}")
# --- Ridge with poly (regularized) ---
ridge_poly = Ridge(alpha=ridge_cv.best_params_['alpha']).fit(X_train_poly, y_train)
pred_ridge = ridge_poly.predict(X_test_poly)
results_feature_maps.append(evaluate_model(y_test, pred_ridge, "Ridge (poly deg=2)"))


# do the same with Lasso regression
lasso_cv = GridSearchCV(Lasso(max_iter=10000), param_grid={"alpha": [0.001, 0.01, 0.1, 1.0]}, cv=5)
lasso_cv.fit(X_train_poly, y_train)
print(f"Best alpha for Lasso (poly features): {lasso_cv.best_params_['alpha']}")
lasso_poly = Lasso(alpha=lasso_cv.best_params_['alpha'], max_iter=10000).fit(X_train_poly, y_train)
pred_lasso = lasso_poly.predict(X_test_poly)
results_feature_maps.append(evaluate_model(y_test, pred_lasso, "Lasso (poly deg=2)"))

baseline_df = pd.DataFrame(results_feature_maps)
print("=== Classical Baselines (Out-of-Sample) ===")
baseline_df.sort_values("MSE").reset_index(drop=True)
# Out:
# Best alpha for Ridge (poly features): 10.0
# Best alpha for Lasso (poly features): 0.01
# === Classical Baselines (Out-of-Sample) ===
#                 model       MSE       MAE    Corr
# 0  Ridge (poly deg=2)  2.201463  1.164731  0.9672
# 1     LR (poly deg=2)  2.225732  1.155280  0.9669
# 2  Lasso (poly deg=2)  2.250492  1.194461  0.9665
# 3   LR (raw features)  4.566243  1.618328  0.9307

# %%
# --- Ridge with poly (regularized) ---
ridge_poly = Ridge(alpha=1.0).fit(X_train_poly, y_train)
pred_ridge = ridge_poly.predict(X_test_poly)
results_feature_maps.append(evaluate_model(y_test, pred_ridge, "Ridge (poly deg=2)"))

# --- Lasso with poly (sparse regularization) ---
lasso_poly = Lasso(alpha=0.01).fit(X_train_poly, y_train)
pred_lasso = lasso_poly.predict(X_test_poly)
results_feature_maps.append(evaluate_model(y_test, pred_lasso, "Lasso (poly deg=2)"))

# check the number of features that lasso kept non-zero
n_nonzero = np.sum(lasso_poly.coef_ != 0)
print(f"\nLasso selected {n_nonzero} features out of {X_train_poly.shape[1]} total features.")

baseline_df = pd.DataFrame(results_feature_maps)
print("=== Classical Baselines (Out-of-Sample) ===")
baseline_df
# Out:
# Lasso selected 12 features out of 14 total features.
# === Classical Baselines (Out-of-Sample) ===
#                 model       MSE       MAE    Corr
# 0   LR (raw features)  4.566243  1.618328  0.9307
# 1     LR (poly deg=2)  2.225732  1.155280  0.9669
# 2  Ridge (poly deg=2)  2.201463  1.164731  0.9672
# 3  Lasso (poly deg=2)  2.250492  1.194461  0.9665
# 4  Ridge (poly deg=2)  2.220557  1.156471  0.9669
# 5  Lasso (poly deg=2)  2.250492  1.194461  0.9665

# %% [markdown]
# ## 5. Quantum Feature Maps
#
# A **quantum feature map** is a circuit that transforms a classical vector **x** into a quantum state |φ(**x**)⟩. The key idea: by measuring this state, we extract new features that live in a space classical polynomial expansions cannot efficiently reach.
#
# We cover three encoding strategies below, but you are by no means restricted in your implementation.
#
# Pennylane documentation for encoding menthods as template: [pennylane-docs-template](https://docs.pennylane.ai/en/stable/introduction/templates.html)
#
# #### 5.1 Angle Encoding (+ Entanglement Layer)
# - **What it does**: Maps each feature xᵢ to a rotation angle on qubit i: Ry(xᵢ)\|0⟩
# - **Key idea**: Each qubit independently encodes one feature. Entanglement would capture cross feature interactions.
#  This is the quantum equivalent of "just feeding raw features in."
# - **Qubits needed**: One per feature (n_features qubits), using more qubits compared to features is also valid stratergy
# - **Paper**:  Schuld & Petruccione, *Supervised Learning with Quantum Computers* (Springer, 2018)

# %%
# Angle Encoding feature map
# Using Pennylane integration with Amazon Braket for your implementation of your quantum circuits could be a helpful tool

N_QUBITS = 4
N_FEATURES = 4  # X1, X2, X3, X4

dev = qml.device("default.qubit", wires=N_QUBITS) # local simulator 

@qml.qnode(dev_braket_local)
def circuit_angle_basic_entangle(x, weights):
    """
    AngleEmbedding -> BasicEntanglerLayers -> Measurements.
    
    Args:
        x: input features, shape (4,)
        weights: trainable params for entangling layers, shape (n_layers, n_qubits)
    """
    # Encode classical data into qubit rotations
    qml.AngleEmbedding(x, wires=range(N_QUBITS), rotation="Y")
    # Entangling layers with trainable single-qubit rotations + CNOT ring
    qml.BasicEntanglerLayers(weights, wires=range(N_QUBITS))
    
    # Measure single-qubit and pairwise expectations
    single = [qml.expval(qml.PauliZ(i)) for i in range(N_QUBITS)]
    pairs = [
        qml.expval(qml.PauliZ(i) @ qml.PauliZ(j))
        for i in range(N_QUBITS) for j in range(i + 1, N_QUBITS)
    ]
    return single + pairs

# %% [markdown]
# Testing the angle encoding

# %%
# --- Angle Encoding ---
print("=== Angle Encoding ===")
n_layers = 2
weights = pnp.random.uniform(0, 2 * np.pi, size=(n_layers, N_QUBITS), requires_grad=False)
print(qml.draw(circuit_angle_basic_entangle)(X_train_q[0], weights))
fig, ax = qml.draw_mpl(circuit_angle_basic_entangle)(X_train_q[0], weights)
plt.show()
# Out:
# === Angle Encoding ===
# 0: ─╭AngleEmbedding(M0)─╭BasicEntanglerLayers(M1)─┤  <Z> ╭<Z@Z> ╭<Z@Z> ╭<Z@Z>
# 1: ─├AngleEmbedding(M0)─├BasicEntanglerLayers(M1)─┤  <Z> ╰<Z@Z> │      │      ╭<Z@Z> ╭<Z@Z>
# 2: ─├AngleEmbedding(M0)─├BasicEntanglerLayers(M1)─┤  <Z>        ╰<Z@Z> │      ╰<Z@Z> │      ╭<Z@Z>
# 3: ─╰AngleEmbedding(M0)─╰BasicEntanglerLayers(M1)─┤  <Z>               ╰<Z@Z>        ╰<Z@Z> ╰<Z@Z>
#
# M0 =
# [2.19618231 1.56751581 2.0181915  1.50018983]
# M1 =
# [[5.89710059e+00 4.89313009e-03 6.23424909e+00 3.87975075e+00]
#  [3.84313015e+00 4.43989051e-02 1.44905490e-01 3.29725643e+00]]

# %%
def extract_angle_features(X, weights, label="angle"):
    features = []
    for i, x in enumerate(X):
        result = circuit_angle_basic_entangle(x, weights)
        features.append(result)
        if (i + 1) % 1 == 0:
            print(f"  {label}: processed {i + 1}/{len(X)} samples")
    return np.array(features)

Q_train_angle = extract_angle_features(X_train_q, weights, "angle train")
Q_test_angle = extract_angle_features(X_test_q, weights, "angle test")


# Backward-compatible aliases used elsewhere in the notebook
q_train_angle = Q_train_angle
q_test_angle = Q_test_angle
# Out:
#   angle train: processed 1/10000 samples
#   angle train: processed 2/10000 samples
#   angle train: processed 3/10000 samples
#   angle train: processed 4/10000 samples
#   angle train: processed 5/10000 samples
#   angle train: processed 6/10000 samples
#   angle train: processed 7/10000 samples
#   angle train: processed 8/10000 samples
#   angle train: processed 9/10000 samples
#   angle train: processed 10/10000 samples
#   angle train: processed 11/10000 samples
#   angle train: processed 12/10000 samples
#   angle train: processed 13/10000 samples
#   angle train: processed 14/10000 samples
#   angle train: processed 15/10000 samples
#   angle train: processed 16/10000 samples
#   angle train: processed 17/10000 samples
#   angle train: processed 18/10000 samples
#   angle train: processed 19/10000 samples
#   angle train: processed 20/10000 samples
#   angle train: processed 21/10000 samples
#   angle train: processed 22/10000 samples
#   angle train: processed 23/10000 samples
#   angle train: processed 24/10000 samples
#   angle train: processed 25/10000 samples
#   angle train: processed 26/10000 samples
#   angle train: processed 27/10000 samples
#   angle train: processed 28/10000 samples
#   angle train: processed 29/10000 samples
#   angle train: processed 30/10000 samples
#   angle train: processed 31/10000 samples
#   angle train: processed 32/10000 samples
#   angle train: processed 33/10000 samples
#   angle train: processed 34/10000 samples
#   angle train: processed 35/10000 samples
#   angle train: processed 36/10000 samples
#   angle train: processed 37/10000 samples
#   angle train: processed 38/10000 samples
#   angle train: processed 39/10000 samples
#   angle train: processed 40/10000 samples
#   angle train: processed 41/10000 samples
#   angle train: processed 42/10000 samples
#   angle train: processed 43/10000 samples
#   angle train: processed 44/10000 samples
#   angle train: processed 45/10000 samples
#   angle train: processed 46/10000 samples
#   angle train: processed 47/10000 samples
#   angle train: processed 48/10000 samples
#   angle train: processed 49/10000 samples
#   angle train: processed 50/10000 samples
#   angle train: processed 51/10000 samples
#   angle train: processed 52/10000 samples
#   angle train: processed 53/10000 samples
#   angle train: processed 54/10000 samples
#   angle train: processed 55/10000 samples
#   angle train: processed 56/10000 samples
#   angle train: processed 57/10000 samples
#   angle train: processed 58/10000 samples
#   angle train: processed 59/10000 samples
#   angle train: processed 60/10000 samples
#   angle train: processed 61/10000 samples
#   angle train: processed 62/10000 samples
#   angle train: processed 63/10000 samples
#   angle train: processed 64/10000 samples
#   angle train: processed 65/10000 samples
#   angle train: processed 66/10000 samples
#   angle train: processed 67/10000 samples
#   angle train: processed 68/10000 samples
#   angle train: processed 69/10000 samples
#   angle train: processed 70/10000 samples
#   angle train: processed 71/10000 samples
#   angle train: processed 72/10000 samples
#   angle train: processed 73/10000 samples
#   angle train: processed 74/10000 samples
#   angle train: processed 75/10000 samples
#   angle train: processed 76/10000 samples
#   angle train: processed 77/10000 samples
#   angle train: processed 78/10000 samples
#   angle train: processed 79/10000 samples
#   angle train: processed 80/10000 samples
#   angle train: processed 81/10000 samples
#   angle train: processed 82/10000 samples
#   angle train: processed 83/10000 samples
#   angle train: processed 84/10000 samples
#   angle train: processed 85/10000 samples
#   angle train: processed 86/10000 samples
#   angle train: processed 87/10000 samples
#   angle train: processed 88/10000 samples
#   angle train: processed 89/10000 samples
#   angle train: processed 90/10000 samples
#   angle train: processed 91/10000 samples
#   angle train: processed 92/10000 samples
#   angle train: processed 93/10000 samples
#   angle train: processed 94/10000 samples
#   angle train: processed 95/10000 samples
#   angle train: processed 96/10000 samples
#   angle train: processed 97/10000 samples
#   angle train: processed 98/10000 samples
#   angle train: processed 99/10000 samples
#   angle train: processed 100/10000 samples
#   angle train: processed 101/10000 samples
#   angle train: processed 102/10000 samples
#   angle train: processed 103/10000 samples
#   angle train: processed 104/10000 samples
#   angle train: processed 105/10000 samples
#   angle train: processed 106/10000 samples
#   angle train: processed 107/10000 samples
#   angle train: processed 108/10000 samples
#   angle train: processed 109/10000 samples
#   angle train: processed 110/10000 samples
#   angle train: processed 111/10000 samples
#   angle train: processed 112/10000 samples
#   angle train: processed 113/10000 samples
#   angle train: processed 114/10000 samples
#   angle train: processed 115/10000 samples
#   angle train: processed 116/10000 samples
#   angle train: processed 117/10000 samples
#   angle train: processed 118/10000 samples
#   angle train: processed 119/10000 samples
#   angle train: processed 120/10000 samples
#   angle train: processed 121/10000 samples
#   angle train: processed 122/10000 samples
#   angle train: processed 123/10000 samples
#   angle train: processed 124/10000 samples
#   angle train: processed 125/10000 samples
#   angle train: processed 126/10000 samples
#   angle train: processed 127/10000 samples
#   angle train: processed 128/10000 samples
#   angle train: processed 129/10000 samples
#   angle train: processed 130/10000 samples
#   angle train: processed 131/10000 samples
#   angle train: processed 132/10000 samples
#   angle train: processed 133/10000 samples
#   angle train: processed 134/10000 samples
#   angle train: processed 135/10000 samples
#   angle train: processed 136/10000 samples
#   angle train: processed 137/10000 samples
#   angle train: processed 138/10000 samples
#   angle train: processed 139/10000 samples
#   angle train: processed 140/10000 samples
#   angle train: processed 141/10000 samples
#   angle train: processed 142/10000 samples
#   angle train: processed 143/10000 samples
#   angle train: processed 144/10000 samples
#   angle train: processed 145/10000 samples
#   angle train: processed 146/10000 samples
#   angle train: processed 147/10000 samples
#   angle train: processed 148/10000 samples
#   angle train: processed 149/10000 samples
#   angle train: processed 150/10000 samples
#   angle train: processed 151/10000 samples
#   angle train: processed 152/10000 samples
#   angle train: processed 153/10000 samples
#   angle train: processed 154/10000 samples
#   angle train: processed 155/10000 samples
#   angle train: processed 156/10000 samples
#   angle train: processed 157/10000 samples
#   angle train: processed 158/10000 samples
#   angle train: processed 159/10000 samples
#   angle train: processed 160/10000 samples
#   angle train: processed 161/10000 samples
#   angle train: processed 162/10000 samples
#   angle train: processed 163/10000 samples
#   angle train: processed 164/10000 samples
#   angle train: processed 165/10000 samples
#   angle train: processed 166/10000 samples
#   angle train: processed 167/10000 samples
#   angle train: processed 168/10000 samples
#   angle train: processed 169/10000 samples
#   angle train: processed 170/10000 samples
#   angle train: processed 171/10000 samples
#   angle train: processed 172/10000 samples
#   angle train: processed 173/10000 samples
#   angle train: processed 174/10000 samples
#   angle train: processed 175/10000 samples
#   angle train: processed 176/10000 samples
#   angle train: processed 177/10000 samples
#   angle train: processed 178/10000 samples
#   angle train: processed 179/10000 samples
#   angle train: processed 180/10000 samples
#   angle train: processed 181/10000 samples
#   angle train: processed 182/10000 samples
#   angle train: processed 183/10000 samples
#   angle train: processed 184/10000 samples
#   angle train: processed 185/10000 samples
#   angle train: processed 186/10000 samples
#   angle train: processed 187/10000 samples
#   angle train: processed 188/10000 samples
#   angle train: processed 189/10000 samples
#   angle train: processed 190/10000 samples
#   angle train: processed 191/10000 samples
#   angle train: processed 192/10000 samples
#   angle train: processed 193/10000 samples
#   angle train: processed 194/10000 samples
#   angle train: processed 195/10000 samples
#   angle train: processed 196/10000 samples
#   angle train: processed 197/10000 samples
#   angle train: processed 198/10000 samples
#   angle train: processed 199/10000 samples
#   angle train: processed 200/10000 samples
#   angle train: processed 201/10000 samples
#   angle train: processed 202/10000 samples
#   angle train: processed 203/10000 samples
#   angle train: processed 204/10000 samples
#   angle train: processed 205/10000 samples
#   angle train: processed 206/10000 samples
#   angle train: processed 207/10000 samples
#   angle train: processed 208/10000 samples
#   angle train: processed 209/10000 samples
#   angle train: processed 210/10000 samples
#   angle train: processed 211/10000 samples
#   angle train: processed 212/10000 samples
#   angle train: processed 213/10000 samples
#   angle train: processed 214/10000 samples
#   angle train: processed 215/10000 samples
#   angle train: processed 216/10000 samples
#   angle train: processed 217/10000 samples
#   angle train: processed 218/10000 samples
#   angle train: processed 219/10000 samples
#   angle train: processed 220/10000 samples
#   angle train: processed 221/10000 samples
#   angle train: processed 222/10000 samples
#   angle train: processed 223/10000 samples
#   angle train: processed 224/10000 samples
#   angle train: processed 225/10000 samples
#   angle train: processed 226/10000 samples
#   angle train: processed 227/10000 samples
#   angle train: processed 228/10000 samples
#   angle train: processed 229/10000 samples
#   angle train: processed 230/10000 samples
#   angle train: processed 231/10000 samples
#   angle train: processed 232/10000 samples
#   angle train: processed 233/10000 samples
#   angle train: processed 234/10000 samples
#   angle train: processed 235/10000 samples
#   angle train: processed 236/10000 samples
#   angle train: processed 237/10000 samples
#   angle train: processed 238/10000 samples
#   angle train: processed 239/10000 samples
#   angle train: processed 240/10000 samples
#   angle train: processed 241/10000 samples
#   angle train: processed 242/10000 samples
#   angle train: processed 243/10000 samples
#   angle train: processed 244/10000 samples
#   angle train: processed 245/10000 samples
#   angle train: processed 246/10000 samples
#   angle train: processed 247/10000 samples
#   angle train: processed 248/10000 samples
#   angle train: processed 249/10000 samples
#   angle train: processed 250/10000 samples
#   angle train: processed 251/10000 samples
#   angle train: processed 252/10000 samples
#   angle train: processed 253/10000 samples
#   angle train: processed 254/10000 samples
#   angle train: processed 255/10000 samples
#   angle train: processed 256/10000 samples
#   angle train: processed 257/10000 samples
#   angle train: processed 258/10000 samples
#   angle train: processed 259/10000 samples
#   angle train: processed 260/10000 samples
#   angle train: processed 261/10000 samples
#   angle train: processed 262/10000 samples
#   angle train: processed 263/10000 samples
#   angle train: processed 264/10000 samples
#   angle train: processed 265/10000 samples
#   angle train: processed 266/10000 samples
#   angle train: processed 267/10000 samples
#   angle train: processed 268/10000 samples
#   angle train: processed 269/10000 samples
#   angle train: processed 270/10000 samples
#   angle train: processed 271/10000 samples
#   angle train: processed 272/10000 samples
#   angle train: processed 273/10000 samples
#   angle train: processed 274/10000 samples
#   angle train: processed 275/10000 samples
#   angle train: processed 276/10000 samples
#   angle train: processed 277/10000 samples
#   angle train: processed 278/10000 samples
#   angle train: processed 279/10000 samples
#   angle train: processed 280/10000 samples
#   angle train: processed 281/10000 samples
#   angle train: processed 282/10000 samples
#   angle train: processed 283/10000 samples
#   angle train: processed 284/10000 samples
#   angle train: processed 285/10000 samples
#   angle train: processed 286/10000 samples
#   angle train: processed 287/10000 samples
#   angle train: processed 288/10000 samples
#   angle train: processed 289/10000 samples
#   angle train: processed 290/10000 samples
#   angle train: processed 291/10000 samples
#   angle train: processed 292/10000 samples
#   angle train: processed 293/10000 samples
#   angle train: processed 294/10000 samples
#   angle train: processed 295/10000 samples
#   angle train: processed 296/10000 samples
#   angle train: processed 297/10000 samples
#   angle train: processed 298/10000 samples
#   angle train: processed 299/10000 samples
#   angle train: processed 300/10000 samples
#   angle train: processed 301/10000 samples
#   angle train: processed 302/10000 samples
#   angle train: processed 303/10000 samples
#   angle train: processed 304/10000 samples
#   angle train: processed 305/10000 samples
#   angle train: processed 306/10000 samples
#   angle train: processed 307/10000 samples
#   angle train: processed 308/10000 samples
#   angle train: processed 309/10000 samples
#   angle train: processed 310/10000 samples
#   angle train: processed 311/10000 samples
#   angle train: processed 312/10000 samples
#   angle train: processed 313/10000 samples
#   angle train: processed 314/10000 samples
#   angle train: processed 315/10000 samples
#   angle train: processed 316/10000 samples
#   angle train: processed 317/10000 samples
#   angle train: processed 318/10000 samples
#   angle train: processed 319/10000 samples
#   angle train: processed 320/10000 samples
#   angle train: processed 321/10000 samples
#   angle train: processed 322/10000 samples
#   angle train: processed 323/10000 samples
#   angle train: processed 324/10000 samples
#   angle train: processed 325/10000 samples
#   angle train: processed 326/10000 samples
#   angle train: processed 327/10000 samples
#   angle train: processed 328/10000 samples
#   angle train: processed 329/10000 samples
#   angle train: processed 330/10000 samples
#   angle train: processed 331/10000 samples
#   angle train: processed 332/10000 samples
#   angle train: processed 333/10000 samples
#   angle train: processed 334/10000 samples
#   angle train: processed 335/10000 samples
#   angle train: processed 336/10000 samples
#   angle train: processed 337/10000 samples
#   angle train: processed 338/10000 samples
#   angle train: processed 339/10000 samples
#   angle train: processed 340/10000 samples
#   angle train: processed 341/10000 samples
#   angle train: processed 342/10000 samples
#   angle train: processed 343/10000 samples
#   angle train: processed 344/10000 samples
#   angle train: processed 345/10000 samples
#   angle train: processed 346/10000 samples
#   angle train: processed 347/10000 samples
#   angle train: processed 348/10000 samples
#   angle train: processed 349/10000 samples
#   angle train: processed 350/10000 samples
#   angle train: processed 351/10000 samples
#   angle train: processed 352/10000 samples
#   angle train: processed 353/10000 samples
#   angle train: processed 354/10000 samples
#   angle train: processed 355/10000 samples
#   angle train: processed 356/10000 samples
#   angle train: processed 357/10000 samples
#   angle train: processed 358/10000 samples
#   angle train: processed 359/10000 samples
#   angle train: processed 360/10000 samples
#   angle train: processed 361/10000 samples
#   angle train: processed 362/10000 samples
#   angle train: processed 363/10000 samples
#   angle train: processed 364/10000 samples
#   angle train: processed 365/10000 samples
#   angle train: processed 366/10000 samples
#   angle train: processed 367/10000 samples
#   angle train: processed 368/10000 samples
#   angle train: processed 369/10000 samples
#   angle train: processed 370/10000 samples
#   angle train: processed 371/10000 samples
#   angle train: processed 372/10000 samples
#   angle train: processed 373/10000 samples
#   angle train: processed 374/10000 samples
#   angle train: processed 375/10000 samples
#   angle train: processed 376/10000 samples
#   angle train: processed 377/10000 samples
#   angle train: processed 378/10000 samples
#   angle train: processed 379/10000 samples
#   angle train: processed 380/10000 samples
#   angle train: processed 381/10000 samples
#   angle train: processed 382/10000 samples
#   angle train: processed 383/10000 samples
#   angle train: processed 384/10000 samples
#   angle train: processed 385/10000 samples
#   angle train: processed 386/10000 samples
#   angle train: processed 387/10000 samples
#   angle train: processed 388/10000 samples
#   angle train: processed 389/10000 samples
#   angle train: processed 390/10000 samples
#   angle train: processed 391/10000 samples
#   angle train: processed 392/10000 samples
#   angle train: processed 393/10000 samples
#   angle train: processed 394/10000 samples
#   angle train: processed 395/10000 samples
#   angle train: processed 396/10000 samples
#   angle train: processed 397/10000 samples
#   angle train: processed 398/10000 samples
#   angle train: processed 399/10000 samples
#   angle train: processed 400/10000 samples
#   angle train: processed 401/10000 samples
#   angle train: processed 402/10000 samples
#   angle train: processed 403/10000 samples
#   angle train: processed 404/10000 samples
#   angle train: processed 405/10000 samples
#   angle train: processed 406/10000 samples
#   angle train: processed 407/10000 samples
#   angle train: processed 408/10000 samples
#   angle train: processed 409/10000 samples
#   angle train: processed 410/10000 samples
#   angle train: processed 411/10000 samples
#   angle train: processed 412/10000 samples
#   angle train: processed 413/10000 samples
#   angle train: processed 414/10000 samples
#   angle train: processed 415/10000 samples
#   angle train: processed 416/10000 samples
#   angle train: processed 417/10000 samples
#   angle train: processed 418/10000 samples
#   angle train: processed 419/10000 samples
#   angle train: processed 420/10000 samples
#   angle train: processed 421/10000 samples
#   angle train: processed 422/10000 samples
#   angle train: processed 423/10000 samples
#   angle train: processed 424/10000 samples
#   angle train: processed 425/10000 samples
#   angle train: processed 426/10000 samples
#   angle train: processed 427/10000 samples
#   angle train: processed 428/10000 samples
#   angle train: processed 429/10000 samples
#   angle train: processed 430/10000 samples
#   angle train: processed 431/10000 samples
#   angle train: processed 432/10000 samples
#   angle train: processed 433/10000 samples
#   angle train: processed 434/10000 samples
#   angle train: processed 435/10000 samples
#   angle train: processed 436/10000 samples
#   angle train: processed 437/10000 samples
#   angle train: processed 438/10000 samples
#   angle train: processed 439/10000 samples
#   angle train: processed 440/10000 samples
#   angle train: processed 441/10000 samples
#   angle train: processed 442/10000 samples
#   angle train: processed 443/10000 samples
#   angle train: processed 444/10000 samples
#   angle train: processed 445/10000 samples
#   angle train: processed 446/10000 samples
#   angle train: processed 447/10000 samples
#   angle train: processed 448/10000 samples
#   angle train: processed 449/10000 samples
#   angle train: processed 450/10000 samples
#   angle train: processed 451/10000 samples
#   angle train: processed 452/10000 samples
#   angle train: processed 453/10000 samples
#   angle train: processed 454/10000 samples
#   angle train: processed 455/10000 samples
#   angle train: processed 456/10000 samples
#   angle train: processed 457/10000 samples
#   angle train: processed 458/10000 samples
#   angle train: processed 459/10000 samples
#   angle train: processed 460/10000 samples
#   angle train: processed 461/10000 samples
#   angle train: processed 462/10000 samples
#   angle train: processed 463/10000 samples
#   angle train: processed 464/10000 samples
#   angle train: processed 465/10000 samples
#   angle train: processed 466/10000 samples
#   angle train: processed 467/10000 samples
#   angle train: processed 468/10000 samples
#   angle train: processed 469/10000 samples
#   angle train: processed 470/10000 samples
#   angle train: processed 471/10000 samples
#   angle train: processed 472/10000 samples
#   angle train: processed 473/10000 samples
#   angle train: processed 474/10000 samples
#   angle train: processed 475/10000 samples
#   angle train: processed 476/10000 samples
#   angle train: processed 477/10000 samples
#   angle train: processed 478/10000 samples
#   angle train: processed 479/10000 samples
#   angle train: processed 480/10000 samples
#   angle train: processed 481/10000 samples
#   angle train: processed 482/10000 samples
#   angle train: processed 483/10000 samples
#   angle train: processed 484/10000 samples
#   angle train: processed 485/10000 samples
#   angle train: processed 486/10000 samples
#   angle train: processed 487/10000 samples
#   angle train: processed 488/10000 samples
#   angle train: processed 489/10000 samples
#   angle train: processed 490/10000 samples
#   angle train: processed 491/10000 samples
#   angle train: processed 492/10000 samples
#   angle train: processed 493/10000 samples
#   angle train: processed 494/10000 samples
#   angle train: processed 495/10000 samples
#   angle train: processed 496/10000 samples
#   angle train: processed 497/10000 samples
#   angle train: processed 498/10000 samples
#   angle train: processed 499/10000 samples
#   angle train: processed 500/10000 samples
#   angle train: processed 501/10000 samples
#   angle train: processed 502/10000 samples
#   angle train: processed 503/10000 samples
#   angle train: processed 504/10000 samples
#   angle train: processed 505/10000 samples
#   angle train: processed 506/10000 samples
#   angle train: processed 507/10000 samples
#   angle train: processed 508/10000 samples
#   angle train: processed 509/10000 samples
#   angle train: processed 510/10000 samples
#   angle train: processed 511/10000 samples
#   angle train: processed 512/10000 samples
#   angle train: processed 513/10000 samples
#   angle train: processed 514/10000 samples
#   angle train: processed 515/10000 samples
#   angle train: processed 516/10000 samples
#   angle train: processed 517/10000 samples
#   angle train: processed 518/10000 samples
#   angle train: processed 519/10000 samples
#   angle train: processed 520/10000 samples
#   angle train: processed 521/10000 samples
#   angle train: processed 522/10000 samples
#   angle train: processed 523/10000 samples
#   angle train: processed 524/10000 samples
#   angle train: processed 525/10000 samples
#   angle train: processed 526/10000 samples
#   angle train: processed 527/10000 samples
#   angle train: processed 528/10000 samples
#   angle train: processed 529/10000 samples
#   angle train: processed 530/10000 samples
#   angle train: processed 531/10000 samples
#   angle train: processed 532/10000 samples
#   angle train: processed 533/10000 samples
#   angle train: processed 534/10000 samples
#   angle train: processed 535/10000 samples
#   angle train: processed 536/10000 samples
#   angle train: processed 537/10000 samples
#   angle train: processed 538/10000 samples
#   angle train: processed 539/10000 samples
#   angle train: processed 540/10000 samples
#   angle train: processed 541/10000 samples
#   angle train: processed 542/10000 samples
#   angle train: processed 543/10000 samples
#   angle train: processed 544/10000 samples
#   angle train: processed 545/10000 samples
#   angle train: processed 546/10000 samples
#   angle train: processed 547/10000 samples
#   angle train: processed 548/10000 samples
#   angle train: processed 549/10000 samples
#   angle train: processed 550/10000 samples
#   angle train: processed 551/10000 samples
#   angle train: processed 552/10000 samples
#   angle train: processed 553/10000 samples
#   angle train: processed 554/10000 samples
#   angle train: processed 555/10000 samples
#   angle train: processed 556/10000 samples
#   angle train: processed 557/10000 samples
#   angle train: processed 558/10000 samples
#   angle train: processed 559/10000 samples
#   angle train: processed 560/10000 samples
#   angle train: processed 561/10000 samples
#   angle train: processed 562/10000 samples
#   angle train: processed 563/10000 samples
#   angle train: processed 564/10000 samples
#   angle train: processed 565/10000 samples
#   angle train: processed 566/10000 samples
#   angle train: processed 567/10000 samples
#   angle train: processed 568/10000 samples
#   angle train: processed 569/10000 samples
#   angle train: processed 570/10000 samples
#   angle train: processed 571/10000 samples
#   angle train: processed 572/10000 samples
#   angle train: processed 573/10000 samples
#   angle train: processed 574/10000 samples
#   angle train: processed 575/10000 samples
#   angle train: processed 576/10000 samples
#   angle train: processed 577/10000 samples
#   angle train: processed 578/10000 samples
#   angle train: processed 579/10000 samples
#   angle train: processed 580/10000 samples
#   angle train: processed 581/10000 samples
#   angle train: processed 582/10000 samples
#   angle train: processed 583/10000 samples
#   angle train: processed 584/10000 samples
#   angle train: processed 585/10000 samples
#   angle train: processed 586/10000 samples
#   angle train: processed 587/10000 samples
#   angle train: processed 588/10000 samples
#   angle train: processed 589/10000 samples
#   angle train: processed 590/10000 samples
#   angle train: processed 591/10000 samples
#   angle train: processed 592/10000 samples
#   angle train: processed 593/10000 samples
#   angle train: processed 594/10000 samples
#   angle train: processed 595/10000 samples
#   angle train: processed 596/10000 samples
#   angle train: processed 597/10000 samples
#   angle train: processed 598/10000 samples
#   angle train: processed 599/10000 samples
#   angle train: processed 600/10000 samples
#   angle train: processed 601/10000 samples
#   angle train: processed 602/10000 samples
#   angle train: processed 603/10000 samples
#   angle train: processed 604/10000 samples
#   angle train: processed 605/10000 samples
#   angle train: processed 606/10000 samples
#   angle train: processed 607/10000 samples
#   angle train: processed 608/10000 samples
#   angle train: processed 609/10000 samples
#   angle train: processed 610/10000 samples
#   angle train: processed 611/10000 samples
#   angle train: processed 612/10000 samples
#   angle train: processed 613/10000 samples
#   angle train: processed 614/10000 samples
#   angle train: processed 615/10000 samples
#   angle train: processed 616/10000 samples
#   angle train: processed 617/10000 samples
#   angle train: processed 618/10000 samples
#   angle train: processed 619/10000 samples
#   angle train: processed 620/10000 samples
#   angle train: processed 621/10000 samples
#   angle train: processed 622/10000 samples
#   angle train: processed 623/10000 samples
#   angle train: processed 624/10000 samples
#   angle train: processed 625/10000 samples
#   angle train: processed 626/10000 samples
#   angle train: processed 627/10000 samples
#   angle train: processed 628/10000 samples
#   angle train: processed 629/10000 samples
#   angle train: processed 630/10000 samples
#   angle train: processed 631/10000 samples
#   angle train: processed 632/10000 samples
#   angle train: processed 633/10000 samples
#   angle train: processed 634/10000 samples
#   angle train: processed 635/10000 samples
#   angle train: processed 636/10000 samples
#   angle train: processed 637/10000 samples
#   angle train: processed 638/10000 samples
#   angle train: processed 639/10000 samples
#   angle train: processed 640/10000 samples
#   angle train: processed 641/10000 samples
#   angle train: processed 642/10000 samples
#   angle train: processed 643/10000 samples
#   angle train: processed 644/10000 samples
#   angle train: processed 645/10000 samples
#   angle train: processed 646/10000 samples
#   angle train: processed 647/10000 samples
#   angle train: processed 648/10000 samples
#   angle train: processed 649/10000 samples
#   angle train: processed 650/10000 samples
#   angle train: processed 651/10000 samples
#   angle train: processed 652/10000 samples
#   angle train: processed 653/10000 samples
#   angle train: processed 654/10000 samples
#   angle train: processed 655/10000 samples
#   angle train: processed 656/10000 samples
#   angle train: processed 657/10000 samples
#   angle train: processed 658/10000 samples
#   angle train: processed 659/10000 samples
#   angle train: processed 660/10000 samples
#   angle train: processed 661/10000 samples
#   angle train: processed 662/10000 samples
#   angle train: processed 663/10000 samples
#   angle train: processed 664/10000 samples
#   angle train: processed 665/10000 samples
#   angle train: processed 666/10000 samples
#   angle train: processed 667/10000 samples
#   angle train: processed 668/10000 samples
#   angle train: processed 669/10000 samples
#   angle train: processed 670/10000 samples
#   angle train: processed 671/10000 samples
#   angle train: processed 672/10000 samples
#   angle train: processed 673/10000 samples
#   angle train: processed 674/10000 samples
#   angle train: processed 675/10000 samples
#   angle train: processed 676/10000 samples
#   angle train: processed 677/10000 samples
#   angle train: processed 678/10000 samples
#   angle train: processed 679/10000 samples
#   angle train: processed 680/10000 samples
#   angle train: processed 681/10000 samples
#   angle train: processed 682/10000 samples
#   angle train: processed 683/10000 samples
#   angle train: processed 684/10000 samples
#   angle train: processed 685/10000 samples
#   angle train: processed 686/10000 samples
#   angle train: processed 687/10000 samples
#   angle train: processed 688/10000 samples
#   angle train: processed 689/10000 samples
#   angle train: processed 690/10000 samples
#   angle train: processed 691/10000 samples
#   angle train: processed 692/10000 samples
#   angle train: processed 693/10000 samples
#   angle train: processed 694/10000 samples
#   angle train: processed 695/10000 samples
#   angle train: processed 696/10000 samples
#   angle train: processed 697/10000 samples
#   angle train: processed 698/10000 samples
#   angle train: processed 699/10000 samples
#   angle train: processed 700/10000 samples
#   angle train: processed 701/10000 samples
#   angle train: processed 702/10000 samples
#   angle train: processed 703/10000 samples
#   angle train: processed 704/10000 samples
#   angle train: processed 705/10000 samples
#   angle train: processed 706/10000 samples
#   angle train: processed 707/10000 samples
#   angle train: processed 708/10000 samples
#   angle train: processed 709/10000 samples
#   angle train: processed 710/10000 samples
#   angle train: processed 711/10000 samples
#   angle train: processed 712/10000 samples
#   angle train: processed 713/10000 samples
#   angle train: processed 714/10000 samples
#   angle train: processed 715/10000 samples
#   angle train: processed 716/10000 samples
#   angle train: processed 717/10000 samples
#   angle train: processed 718/10000 samples
#   angle train: processed 719/10000 samples
#   angle train: processed 720/10000 samples
#   angle train: processed 721/10000 samples
#   angle train: processed 722/10000 samples
#   angle train: processed 723/10000 samples
#   angle train: processed 724/10000 samples
#   angle train: processed 725/10000 samples
#   angle train: processed 726/10000 samples
#   angle train: processed 727/10000 samples
#   angle train: processed 728/10000 samples
#   angle train: processed 729/10000 samples
#   angle train: processed 730/10000 samples
#   angle train: processed 731/10000 samples
#   angle train: processed 732/10000 samples
#   angle train: processed 733/10000 samples
#   angle train: processed 734/10000 samples
#   angle train: processed 735/10000 samples
#   angle train: processed 736/10000 samples
#   angle train: processed 737/10000 samples
#   angle train: processed 738/10000 samples
#   angle train: processed 739/10000 samples
#   angle train: processed 740/10000 samples
#   angle train: processed 741/10000 samples
#   angle train: processed 742/10000 samples
#   angle train: processed 743/10000 samples
#   angle train: processed 744/10000 samples
#   angle train: processed 745/10000 samples
#   angle train: processed 746/10000 samples
#   angle train: processed 747/10000 samples
#   angle train: processed 748/10000 samples
#   angle train: processed 749/10000 samples
#   angle train: processed 750/10000 samples
#   angle train: processed 751/10000 samples
#   angle train: processed 752/10000 samples
#   angle train: processed 753/10000 samples
#   angle train: processed 754/10000 samples
#   angle train: processed 755/10000 samples
#   angle train: processed 756/10000 samples
#   angle train: processed 757/10000 samples
#   angle train: processed 758/10000 samples
#   angle train: processed 759/10000 samples
#   angle train: processed 760/10000 samples
#   angle train: processed 761/10000 samples
#   angle train: processed 762/10000 samples
#   angle train: processed 763/10000 samples
#   angle train: processed 764/10000 samples
#   angle train: processed 765/10000 samples
#   angle train: processed 766/10000 samples
#   angle train: processed 767/10000 samples
#   angle train: processed 768/10000 samples
#   angle train: processed 769/10000 samples
#   angle train: processed 770/10000 samples
#   angle train: processed 771/10000 samples
#   angle train: processed 772/10000 samples
#   angle train: processed 773/10000 samples
#   angle train: processed 774/10000 samples
#   angle train: processed 775/10000 samples
#   angle train: processed 776/10000 samples
#   angle train: processed 777/10000 samples
#   angle train: processed 778/10000 samples
#   angle train: processed 779/10000 samples
#   angle train: processed 780/10000 samples
#   angle train: processed 781/10000 samples
#   angle train: processed 782/10000 samples
#   angle train: processed 783/10000 samples
#   angle train: processed 784/10000 samples
#   angle train: processed 785/10000 samples
#   angle train: processed 786/10000 samples
#   angle train: processed 787/10000 samples
#   angle train: processed 788/10000 samples
#   angle train: processed 789/10000 samples
#   angle train: processed 790/10000 samples
#   angle train: processed 791/10000 samples
#   angle train: processed 792/10000 samples
#   angle train: processed 793/10000 samples
#   angle train: processed 794/10000 samples
#   angle train: processed 795/10000 samples
#   angle train: processed 796/10000 samples
#   angle train: processed 797/10000 samples
#   angle train: processed 798/10000 samples
#   angle train: processed 799/10000 samples
#   angle train: processed 800/10000 samples
#   angle train: processed 801/10000 samples
#   angle train: processed 802/10000 samples
#   angle train: processed 803/10000 samples
#   angle train: processed 804/10000 samples
#   angle train: processed 805/10000 samples
#   angle train: processed 806/10000 samples
#   angle train: processed 807/10000 samples
#   angle train: processed 808/10000 samples
#   angle train: processed 809/10000 samples
#   angle train: processed 810/10000 samples
#   angle train: processed 811/10000 samples
#   angle train: processed 812/10000 samples
#   angle train: processed 813/10000 samples
#   angle train: processed 814/10000 samples
#   angle train: processed 815/10000 samples
#   angle train: processed 816/10000 samples
#   angle train: processed 817/10000 samples
#   angle train: processed 818/10000 samples
#   angle train: processed 819/10000 samples
#   angle train: processed 820/10000 samples
#   angle train: processed 821/10000 samples
#   angle train: processed 822/10000 samples
#   angle train: processed 823/10000 samples
#   angle train: processed 824/10000 samples
#   angle train: processed 825/10000 samples
#   angle train: processed 826/10000 samples
#   angle train: processed 827/10000 samples
#   angle train: processed 828/10000 samples
#   angle train: processed 829/10000 samples
#   angle train: processed 830/10000 samples
#   angle train: processed 831/10000 samples
#   angle train: processed 832/10000 samples
#   angle train: processed 833/10000 samples
#   angle train: processed 834/10000 samples
#   angle train: processed 835/10000 samples
#   angle train: processed 836/10000 samples
#   angle train: processed 837/10000 samples
#   angle train: processed 838/10000 samples
#   angle train: processed 839/10000 samples
#   angle train: processed 840/10000 samples
#   angle train: processed 841/10000 samples
#   angle train: processed 842/10000 samples
#   angle train: processed 843/10000 samples
#   angle train: processed 844/10000 samples
#   angle train: processed 845/10000 samples
#   angle train: processed 846/10000 samples
#   angle train: processed 847/10000 samples
#   angle train: processed 848/10000 samples
#   angle train: processed 849/10000 samples
#   angle train: processed 850/10000 samples
#   angle train: processed 851/10000 samples
#   angle train: processed 852/10000 samples
#   angle train: processed 853/10000 samples
#   angle train: processed 854/10000 samples
#   angle train: processed 855/10000 samples
#   angle train: processed 856/10000 samples
#   angle train: processed 857/10000 samples
#   angle train: processed 858/10000 samples
#   angle train: processed 859/10000 samples
#   angle train: processed 860/10000 samples
#   angle train: processed 861/10000 samples
#   angle train: processed 862/10000 samples
#   angle train: processed 863/10000 samples
#   angle train: processed 864/10000 samples
#   angle train: processed 865/10000 samples
#   angle train: processed 866/10000 samples
#   angle train: processed 867/10000 samples
#   angle train: processed 868/10000 samples
#   angle train: processed 869/10000 samples
#   angle train: processed 870/10000 samples
#   angle train: processed 871/10000 samples
#   angle train: processed 872/10000 samples
#   angle train: processed 873/10000 samples
#   angle train: processed 874/10000 samples
#   angle train: processed 875/10000 samples
#   angle train: processed 876/10000 samples
#   angle train: processed 877/10000 samples
#   angle train: processed 878/10000 samples
#   angle train: processed 879/10000 samples
#   angle train: processed 880/10000 samples
#   angle train: processed 881/10000 samples
#   angle train: processed 882/10000 samples
#   angle train: processed 883/10000 samples
#   angle train: processed 884/10000 samples
#   angle train: processed 885/10000 samples
#   angle train: processed 886/10000 samples
#   angle train: processed 887/10000 samples
#   angle train: processed 888/10000 samples
#   angle train: processed 889/10000 samples
#   angle train: processed 890/10000 samples
#   angle train: processed 891/10000 samples
#   angle train: processed 892/10000 samples
#   angle train: processed 893/10000 samples
#   angle train: processed 894/10000 samples
#   angle train: processed 895/10000 samples
#   angle train: processed 896/10000 samples
#   angle train: processed 897/10000 samples
#   angle train: processed 898/10000 samples
#   angle train: processed 899/10000 samples
#   angle train: processed 900/10000 samples
#   angle train: processed 901/10000 samples
#   angle train: processed 902/10000 samples
#   angle train: processed 903/10000 samples
#   angle train: processed 904/10000 samples
#   angle train: processed 905/10000 samples
#   angle train: processed 906/10000 samples
#   angle train: processed 907/10000 samples
#   angle train: processed 908/10000 samples
#   angle train: processed 909/10000 samples
#   angle train: processed 910/10000 samples
#   angle train: processed 911/10000 samples
#   angle train: processed 912/10000 samples
#   angle train: processed 913/10000 samples
#   angle train: processed 914/10000 samples
#   angle train: processed 915/10000 samples
#   angle train: processed 916/10000 samples
#   angle train: processed 917/10000 samples
#   angle train: processed 918/10000 samples
#   angle train: processed 919/10000 samples
#   angle train: processed 920/10000 samples
#   angle train: processed 921/10000 samples
#   angle train: processed 922/10000 samples
#   angle train: processed 923/10000 samples
#   angle train: processed 924/10000 samples
#   angle train: processed 925/10000 samples
#   angle train: processed 926/10000 samples
#   angle train: processed 927/10000 samples
#   angle train: processed 928/10000 samples
#   angle train: processed 929/10000 samples
#   angle train: processed 930/10000 samples
#   angle train: processed 931/10000 samples
#   angle train: processed 932/10000 samples
#   angle train: processed 933/10000 samples
#   angle train: processed 934/10000 samples
#   angle train: processed 935/10000 samples
#   angle train: processed 936/10000 samples
#   angle train: processed 937/10000 samples
#   angle train: processed 938/10000 samples
#   angle train: processed 939/10000 samples
#   angle train: processed 940/10000 samples
#   angle train: processed 941/10000 samples
#   angle train: processed 942/10000 samples
#   angle train: processed 943/10000 samples
#   angle train: processed 944/10000 samples
#   angle train: processed 945/10000 samples
#   angle train: processed 946/10000 samples
#   angle train: processed 947/10000 samples
#   angle train: processed 948/10000 samples
#   angle train: processed 949/10000 samples
#   angle train: processed 950/10000 samples
#   angle train: processed 951/10000 samples
#   angle train: processed 952/10000 samples
#   angle train: processed 953/10000 samples
#   angle train: processed 954/10000 samples
#   angle train: processed 955/10000 samples
#   angle train: processed 956/10000 samples
#   angle train: processed 957/10000 samples
#   angle train: processed 958/10000 samples
#   angle train: processed 959/10000 samples
#   angle train: processed 960/10000 samples
#   angle train: processed 961/10000 samples
#   angle train: processed 962/10000 samples
#   angle train: processed 963/10000 samples
#   angle train: processed 964/10000 samples
#   angle train: processed 965/10000 samples
#   angle train: processed 966/10000 samples
#   angle train: processed 967/10000 samples
#   angle train: processed 968/10000 samples
#   angle train: processed 969/10000 samples
#   angle train: processed 970/10000 samples
#   angle train: processed 971/10000 samples
#   angle train: processed 972/10000 samples
#   angle train: processed 973/10000 samples
#   angle train: processed 974/10000 samples
#   angle train: processed 975/10000 samples
#   angle train: processed 976/10000 samples
#   angle train: processed 977/10000 samples
#   angle train: processed 978/10000 samples
#   angle train: processed 979/10000 samples
#   angle train: processed 980/10000 samples
#   angle train: processed 981/10000 samples
#   angle train: processed 982/10000 samples
#   angle train: processed 983/10000 samples
#   angle train: processed 984/10000 samples
#   angle train: processed 985/10000 samples
#   angle train: processed 986/10000 samples
#   angle train: processed 987/10000 samples
#   angle train: processed 988/10000 samples
#   angle train: processed 989/10000 samples
#   angle train: processed 990/10000 samples
#   angle train: processed 991/10000 samples
#   angle train: processed 992/10000 samples
#   angle train: processed 993/10000 samples
#   angle train: processed 994/10000 samples
#   angle train: processed 995/10000 samples
#   angle train: processed 996/10000 samples
#   angle train: processed 997/10000 samples
#   angle train: processed 998/10000 samples
#   angle train: processed 999/10000 samples
#   angle train: processed 1000/10000 samples
#   angle train: processed 1001/10000 samples
#   angle train: processed 1002/10000 samples
#   angle train: processed 1003/10000 samples
#   angle train: processed 1004/10000 samples
#   angle train: processed 1005/10000 samples
#   angle train: processed 1006/10000 samples
#   angle train: processed 1007/10000 samples
#   angle train: processed 1008/10000 samples
#   angle train: processed 1009/10000 samples
#   angle train: processed 1010/10000 samples
#   angle train: processed 1011/10000 samples
#   angle train: processed 1012/10000 samples
#   angle train: processed 1013/10000 samples
#   angle train: processed 1014/10000 samples
#   angle train: processed 1015/10000 samples
#   angle train: processed 1016/10000 samples
#   angle train: processed 1017/10000 samples
#   angle train: processed 1018/10000 samples
#   angle train: processed 1019/10000 samples
#   angle train: processed 1020/10000 samples
#   angle train: processed 1021/10000 samples
#   angle train: processed 1022/10000 samples
#   angle train: processed 1023/10000 samples
#   angle train: processed 1024/10000 samples
#   angle train: processed 1025/10000 samples
#   angle train: processed 1026/10000 samples
#   angle train: processed 1027/10000 samples
#   angle train: processed 1028/10000 samples
#   angle train: processed 1029/10000 samples
#   angle train: processed 1030/10000 samples
#   angle train: processed 1031/10000 samples
#   angle train: processed 1032/10000 samples
#   angle train: processed 1033/10000 samples
#   angle train: processed 1034/10000 samples
#   angle train: processed 1035/10000 samples
#   angle train: processed 1036/10000 samples
#   angle train: processed 1037/10000 samples
#   angle train: processed 1038/10000 samples
#   angle train: processed 1039/10000 samples
#   angle train: processed 1040/10000 samples
#   angle train: processed 1041/10000 samples
#   angle train: processed 1042/10000 samples
#   angle train: processed 1043/10000 samples
#   angle train: processed 1044/10000 samples
#   angle train: processed 1045/10000 samples
#   angle train: processed 1046/10000 samples
#   angle train: processed 1047/10000 samples
#   angle train: processed 1048/10000 samples
#   angle train: processed 1049/10000 samples
#   angle train: processed 1050/10000 samples
#   angle train: processed 1051/10000 samples
#   angle train: processed 1052/10000 samples
#   angle train: processed 1053/10000 samples
#   angle train: processed 1054/10000 samples
#   angle train: processed 1055/10000 samples
#   angle train: processed 1056/10000 samples
#   angle train: processed 1057/10000 samples
#   angle train: processed 1058/10000 samples
#   angle train: processed 1059/10000 samples
#   angle train: processed 1060/10000 samples
#   angle train: processed 1061/10000 samples
#   angle train: processed 1062/10000 samples
#   angle train: processed 1063/10000 samples
#   angle train: processed 1064/10000 samples
#   angle train: processed 1065/10000 samples
#   angle train: processed 1066/10000 samples
#   angle train: processed 1067/10000 samples
#   angle train: processed 1068/10000 samples
#   angle train: processed 1069/10000 samples
#   angle train: processed 1070/10000 samples
#   angle train: processed 1071/10000 samples
#   angle train: processed 1072/10000 samples
#   angle train: processed 1073/10000 samples
#   angle train: processed 1074/10000 samples
#   angle train: processed 1075/10000 samples
#   angle train: processed 1076/10000 samples
#   angle train: processed 1077/10000 samples
#   angle train: processed 1078/10000 samples
#   angle train: processed 1079/10000 samples
#   angle train: processed 1080/10000 samples
#   angle train: processed 1081/10000 samples
#   angle train: processed 1082/10000 samples
#   angle train: processed 1083/10000 samples
#   angle train: processed 1084/10000 samples
#   angle train: processed 1085/10000 samples
#   angle train: processed 1086/10000 samples
#   angle train: processed 1087/10000 samples
#   angle train: processed 1088/10000 samples
#   angle train: processed 1089/10000 samples
#   angle train: processed 1090/10000 samples
#   angle train: processed 1091/10000 samples
#   angle train: processed 1092/10000 samples
#   angle train: processed 1093/10000 samples
#   angle train: processed 1094/10000 samples
#   angle train: processed 1095/10000 samples
#   angle train: processed 1096/10000 samples
#   angle train: processed 1097/10000 samples
#   angle train: processed 1098/10000 samples
#   angle train: processed 1099/10000 samples
#   angle train: processed 1100/10000 samples
#   angle train: processed 1101/10000 samples
#   angle train: processed 1102/10000 samples
#   angle train: processed 1103/10000 samples
#   angle train: processed 1104/10000 samples
#   angle train: processed 1105/10000 samples
#   angle train: processed 1106/10000 samples
#   angle train: processed 1107/10000 samples
#   angle train: processed 1108/10000 samples
#   angle train: processed 1109/10000 samples
#   angle train: processed 1110/10000 samples
#   angle train: processed 1111/10000 samples
#   angle train: processed 1112/10000 samples
#   angle train: processed 1113/10000 samples
#   angle train: processed 1114/10000 samples
#   angle train: processed 1115/10000 samples
#   angle train: processed 1116/10000 samples
# ...
#   angle test: processed 9629/10000 samples
#   angle test: processed 9630/10000 samples
#   angle test: processed 9631/10000 samples
#   angle test: processed 9632/10000 samples
#   angle test: processed 9633/10000 samples
#   angle test: processed 9634/10000 samples
#   angle test: processed 9635/10000 samples
#   angle test: processed 9636/10000 samples
#   angle test: processed 9637/10000 samples
#   angle test: processed 9638/10000 samples
#   angle test: processed 9639/10000 samples
#   angle test: processed 9640/10000 samples
#   angle test: processed 9641/10000 samples
#   angle test: processed 9642/10000 samples
#   angle test: processed 9643/10000 samples
#   angle test: processed 9644/10000 samples
#   angle test: processed 9645/10000 samples
#   angle test: processed 9646/10000 samples
#   angle test: processed 9647/10000 samples
#   angle test: processed 9648/10000 samples
#   angle test: processed 9649/10000 samples
#   angle test: processed 9650/10000 samples
#   angle test: processed 9651/10000 samples
#   angle test: processed 9652/10000 samples
#   angle test: processed 9653/10000 samples
#   angle test: processed 9654/10000 samples
#   angle test: processed 9655/10000 samples
#   angle test: processed 9656/10000 samples
#   angle test: processed 9657/10000 samples
#   angle test: processed 9658/10000 samples
#   angle test: processed 9659/10000 samples
#   angle test: processed 9660/10000 samples
#   angle test: processed 9661/10000 samples
#   angle test: processed 9662/10000 samples
#   angle test: processed 9663/10000 samples
#   angle test: processed 9664/10000 samples
#   angle test: processed 9665/10000 samples
#   angle test: processed 9666/10000 samples
#   angle test: processed 9667/10000 samples
#   angle test: processed 9668/10000 samples
#   angle test: processed 9669/10000 samples
#   angle test: processed 9670/10000 samples
#   angle test: processed 9671/10000 samples
#   angle test: processed 9672/10000 samples
#   angle test: processed 9673/10000 samples
#   angle test: processed 9674/10000 samples
#   angle test: processed 9675/10000 samples
#   angle test: processed 9676/10000 samples
#   angle test: processed 9677/10000 samples
#   angle test: processed 9678/10000 samples
#   angle test: processed 9679/10000 samples
#   angle test: processed 9680/10000 samples
#   angle test: processed 9681/10000 samples
#   angle test: processed 9682/10000 samples
#   angle test: processed 9683/10000 samples
#   angle test: processed 9684/10000 samples
#   angle test: processed 9685/10000 samples
#   angle test: processed 9686/10000 samples
#   angle test: processed 9687/10000 samples
#   angle test: processed 9688/10000 samples
#   angle test: processed 9689/10000 samples
#   angle test: processed 9690/10000 samples
#   angle test: processed 9691/10000 samples
#   angle test: processed 9692/10000 samples
#   angle test: processed 9693/10000 samples
#   angle test: processed 9694/10000 samples
#   angle test: processed 9695/10000 samples
#   angle test: processed 9696/10000 samples
#   angle test: processed 9697/10000 samples
#   angle test: processed 9698/10000 samples
#   angle test: processed 9699/10000 samples
#   angle test: processed 9700/10000 samples
#   angle test: processed 9701/10000 samples
#   angle test: processed 9702/10000 samples
#   angle test: processed 9703/10000 samples
#   angle test: processed 9704/10000 samples
#   angle test: processed 9705/10000 samples
#   angle test: processed 9706/10000 samples
#   angle test: processed 9707/10000 samples
#   angle test: processed 9708/10000 samples
#   angle test: processed 9709/10000 samples
#   angle test: processed 9710/10000 samples
#   angle test: processed 9711/10000 samples
#   angle test: processed 9712/10000 samples
#   angle test: processed 9713/10000 samples
#   angle test: processed 9714/10000 samples
#   angle test: processed 9715/10000 samples
#   angle test: processed 9716/10000 samples
#   angle test: processed 9717/10000 samples
#   angle test: processed 9718/10000 samples
#   angle test: processed 9719/10000 samples
#   angle test: processed 9720/10000 samples
#   angle test: processed 9721/10000 samples
#   angle test: processed 9722/10000 samples
#   angle test: processed 9723/10000 samples
#   angle test: processed 9724/10000 samples
#   angle test: processed 9725/10000 samples
#   angle test: processed 9726/10000 samples
#   angle test: processed 9727/10000 samples
#   angle test: processed 9728/10000 samples
#   angle test: processed 9729/10000 samples
#   angle test: processed 9730/10000 samples
#   angle test: processed 9731/10000 samples
#   angle test: processed 9732/10000 samples
#   angle test: processed 9733/10000 samples
#   angle test: processed 9734/10000 samples
#   angle test: processed 9735/10000 samples
#   angle test: processed 9736/10000 samples
#   angle test: processed 9737/10000 samples
#   angle test: processed 9738/10000 samples
#   angle test: processed 9739/10000 samples
#   angle test: processed 9740/10000 samples
#   angle test: processed 9741/10000 samples
#   angle test: processed 9742/10000 samples
#   angle test: processed 9743/10000 samples
#   angle test: processed 9744/10000 samples
#   angle test: processed 9745/10000 samples
#   angle test: processed 9746/10000 samples
#   angle test: processed 9747/10000 samples
#   angle test: processed 9748/10000 samples
#   angle test: processed 9749/10000 samples
#   angle test: processed 9750/10000 samples
#   angle test: processed 9751/10000 samples
#   angle test: processed 9752/10000 samples
#   angle test: processed 9753/10000 samples
#   angle test: processed 9754/10000 samples
#   angle test: processed 9755/10000 samples
#   angle test: processed 9756/10000 samples
#   angle test: processed 9757/10000 samples
#   angle test: processed 9758/10000 samples
#   angle test: processed 9759/10000 samples
#   angle test: processed 9760/10000 samples
#   angle test: processed 9761/10000 samples
#   angle test: processed 9762/10000 samples
#   angle test: processed 9763/10000 samples
#   angle test: processed 9764/10000 samples
#   angle test: processed 9765/10000 samples
#   angle test: processed 9766/10000 samples
#   angle test: processed 9767/10000 samples
#   angle test: processed 9768/10000 samples
#   angle test: processed 9769/10000 samples
#   angle test: processed 9770/10000 samples
#   angle test: processed 9771/10000 samples
#   angle test: processed 9772/10000 samples
#   angle test: processed 9773/10000 samples
#   angle test: processed 9774/10000 samples
#   angle test: processed 9775/10000 samples
#   angle test: processed 9776/10000 samples
#   angle test: processed 9777/10000 samples
#   angle test: processed 9778/10000 samples
#   angle test: processed 9779/10000 samples
#   angle test: processed 9780/10000 samples
#   angle test: processed 9781/10000 samples
#   angle test: processed 9782/10000 samples
#   angle test: processed 9783/10000 samples
#   angle test: processed 9784/10000 samples
#   angle test: processed 9785/10000 samples
#   angle test: processed 9786/10000 samples
#   angle test: processed 9787/10000 samples
#   angle test: processed 9788/10000 samples
#   angle test: processed 9789/10000 samples
#   angle test: processed 9790/10000 samples
#   angle test: processed 9791/10000 samples
#   angle test: processed 9792/10000 samples
#   angle test: processed 9793/10000 samples
#   angle test: processed 9794/10000 samples
#   angle test: processed 9795/10000 samples
#   angle test: processed 9796/10000 samples
#   angle test: processed 9797/10000 samples
#   angle test: processed 9798/10000 samples
#   angle test: processed 9799/10000 samples
#   angle test: processed 9800/10000 samples
#   angle test: processed 9801/10000 samples
#   angle test: processed 9802/10000 samples
#   angle test: processed 9803/10000 samples
#   angle test: processed 9804/10000 samples
#   angle test: processed 9805/10000 samples
#   angle test: processed 9806/10000 samples
#   angle test: processed 9807/10000 samples
#   angle test: processed 9808/10000 samples
#   angle test: processed 9809/10000 samples
#   angle test: processed 9810/10000 samples
#   angle test: processed 9811/10000 samples
#   angle test: processed 9812/10000 samples
#   angle test: processed 9813/10000 samples
#   angle test: processed 9814/10000 samples
#   angle test: processed 9815/10000 samples
#   angle test: processed 9816/10000 samples
#   angle test: processed 9817/10000 samples
#   angle test: processed 9818/10000 samples
#   angle test: processed 9819/10000 samples
#   angle test: processed 9820/10000 samples
#   angle test: processed 9821/10000 samples
#   angle test: processed 9822/10000 samples
#   angle test: processed 9823/10000 samples
#   angle test: processed 9824/10000 samples
#   angle test: processed 9825/10000 samples
#   angle test: processed 9826/10000 samples
#   angle test: processed 9827/10000 samples
#   angle test: processed 9828/10000 samples
#   angle test: processed 9829/10000 samples
#   angle test: processed 9830/10000 samples
#   angle test: processed 9831/10000 samples
#   angle test: processed 9832/10000 samples
#   angle test: processed 9833/10000 samples
#   angle test: processed 9834/10000 samples
#   angle test: processed 9835/10000 samples
#   angle test: processed 9836/10000 samples
#   angle test: processed 9837/10000 samples
#   angle test: processed 9838/10000 samples
#   angle test: processed 9839/10000 samples
#   angle test: processed 9840/10000 samples
#   angle test: processed 9841/10000 samples
#   angle test: processed 9842/10000 samples
#   angle test: processed 9843/10000 samples
#   angle test: processed 9844/10000 samples
#   angle test: processed 9845/10000 samples
#   angle test: processed 9846/10000 samples
#   angle test: processed 9847/10000 samples
#   angle test: processed 9848/10000 samples
#   angle test: processed 9849/10000 samples
#   angle test: processed 9850/10000 samples
#   angle test: processed 9851/10000 samples
#   angle test: processed 9852/10000 samples
#   angle test: processed 9853/10000 samples
#   angle test: processed 9854/10000 samples
#   angle test: processed 9855/10000 samples
#   angle test: processed 9856/10000 samples
#   angle test: processed 9857/10000 samples
#   angle test: processed 9858/10000 samples
#   angle test: processed 9859/10000 samples
#   angle test: processed 9860/10000 samples
#   angle test: processed 9861/10000 samples
#   angle test: processed 9862/10000 samples
#   angle test: processed 9863/10000 samples
#   angle test: processed 9864/10000 samples
#   angle test: processed 9865/10000 samples
#   angle test: processed 9866/10000 samples
#   angle test: processed 9867/10000 samples
#   angle test: processed 9868/10000 samples
#   angle test: processed 9869/10000 samples
#   angle test: processed 9870/10000 samples
#   angle test: processed 9871/10000 samples
#   angle test: processed 9872/10000 samples
#   angle test: processed 9873/10000 samples
#   angle test: processed 9874/10000 samples
#   angle test: processed 9875/10000 samples
#   angle test: processed 9876/10000 samples
#   angle test: processed 9877/10000 samples
#   angle test: processed 9878/10000 samples
#   angle test: processed 9879/10000 samples
#   angle test: processed 9880/10000 samples
#   angle test: processed 9881/10000 samples
#   angle test: processed 9882/10000 samples
#   angle test: processed 9883/10000 samples
#   angle test: processed 9884/10000 samples
#   angle test: processed 9885/10000 samples
#   angle test: processed 9886/10000 samples
#   angle test: processed 9887/10000 samples
#   angle test: processed 9888/10000 samples
#   angle test: processed 9889/10000 samples
#   angle test: processed 9890/10000 samples
#   angle test: processed 9891/10000 samples
#   angle test: processed 9892/10000 samples
#   angle test: processed 9893/10000 samples
#   angle test: processed 9894/10000 samples
#   angle test: processed 9895/10000 samples
#   angle test: processed 9896/10000 samples
#   angle test: processed 9897/10000 samples
#   angle test: processed 9898/10000 samples
#   angle test: processed 9899/10000 samples
#   angle test: processed 9900/10000 samples
#   angle test: processed 9901/10000 samples
#   angle test: processed 9902/10000 samples
#   angle test: processed 9903/10000 samples
#   angle test: processed 9904/10000 samples
#   angle test: processed 9905/10000 samples
#   angle test: processed 9906/10000 samples
#   angle test: processed 9907/10000 samples
#   angle test: processed 9908/10000 samples
#   angle test: processed 9909/10000 samples
#   angle test: processed 9910/10000 samples
#   angle test: processed 9911/10000 samples
#   angle test: processed 9912/10000 samples
#   angle test: processed 9913/10000 samples
#   angle test: processed 9914/10000 samples
#   angle test: processed 9915/10000 samples
#   angle test: processed 9916/10000 samples
#   angle test: processed 9917/10000 samples
#   angle test: processed 9918/10000 samples
#   angle test: processed 9919/10000 samples
#   angle test: processed 9920/10000 samples
#   angle test: processed 9921/10000 samples
#   angle test: processed 9922/10000 samples
#   angle test: processed 9923/10000 samples
#   angle test: processed 9924/10000 samples
#   angle test: processed 9925/10000 samples
#   angle test: processed 9926/10000 samples
#   angle test: processed 9927/10000 samples
#   angle test: processed 9928/10000 samples
#   angle test: processed 9929/10000 samples
#   angle test: processed 9930/10000 samples
#   angle test: processed 9931/10000 samples
#   angle test: processed 9932/10000 samples
#   angle test: processed 9933/10000 samples
#   angle test: processed 9934/10000 samples
#   angle test: processed 9935/10000 samples
#   angle test: processed 9936/10000 samples
#   angle test: processed 9937/10000 samples
#   angle test: processed 9938/10000 samples
#   angle test: processed 9939/10000 samples
#   angle test: processed 9940/10000 samples
#   angle test: processed 9941/10000 samples
#   angle test: processed 9942/10000 samples
#   angle test: processed 9943/10000 samples
#   angle test: processed 9944/10000 samples
#   angle test: processed 9945/10000 samples
#   angle test: processed 9946/10000 samples
#   angle test: processed 9947/10000 samples
#   angle test: processed 9948/10000 samples
#   angle test: processed 9949/10000 samples
#   angle test: processed 9950/10000 samples
#   angle test: processed 9951/10000 samples
#   angle test: processed 9952/10000 samples
#   angle test: processed 9953/10000 samples
#   angle test: processed 9954/10000 samples
#   angle test: processed 9955/10000 samples
#   angle test: processed 9956/10000 samples
#   angle test: processed 9957/10000 samples
#   angle test: processed 9958/10000 samples
#   angle test: processed 9959/10000 samples
#   angle test: processed 9960/10000 samples
#   angle test: processed 9961/10000 samples
#   angle test: processed 9962/10000 samples
#   angle test: processed 9963/10000 samples
#   angle test: processed 9964/10000 samples
#   angle test: processed 9965/10000 samples
#   angle test: processed 9966/10000 samples
#   angle test: processed 9967/10000 samples
#   angle test: processed 9968/10000 samples
#   angle test: processed 9969/10000 samples
#   angle test: processed 9970/10000 samples
#   angle test: processed 9971/10000 samples
#   angle test: processed 9972/10000 samples
#   angle test: processed 9973/10000 samples
#   angle test: processed 9974/10000 samples
#   angle test: processed 9975/10000 samples
#   angle test: processed 9976/10000 samples
#   angle test: processed 9977/10000 samples
#   angle test: processed 9978/10000 samples
#   angle test: processed 9979/10000 samples
#   angle test: processed 9980/10000 samples
#   angle test: processed 9981/10000 samples
#   angle test: processed 9982/10000 samples
#   angle test: processed 9983/10000 samples
#   angle test: processed 9984/10000 samples
#   angle test: processed 9985/10000 samples
#   angle test: processed 9986/10000 samples
#   angle test: processed 9987/10000 samples
#   angle test: processed 9988/10000 samples
#   angle test: processed 9989/10000 samples
#   angle test: processed 9990/10000 samples
#   angle test: processed 9991/10000 samples
#   angle test: processed 9992/10000 samples
#   angle test: processed 9993/10000 samples
#   angle test: processed 9994/10000 samples
#   angle test: processed 9995/10000 samples
#   angle test: processed 9996/10000 samples
#   angle test: processed 9997/10000 samples
#   angle test: processed 9998/10000 samples
#   angle test: processed 9999/10000 samples
#   angle test: processed 10000/10000 samples

# %% [markdown]
# #### 5.2 ZZ Feature Map
#
# - **What it does**: Encodes features using rotations *and* entangling ZZ interactions between qubit pairs, creating cross-feature correlations in the quantum state.
# - **Key idea**: After single-qubit rotations (Hadamard + Rz), pairs of qubits interact through ZZ(xᵢ·xⱼ) gates — implementing exp(i·xᵢ·xⱼ·ZZ). The circuit repeats for multiple layers, increasing expressiveness. This is the feature map with proven classical hardness of simulation in certain regimes.
# - **Paper**: Havlíček et al., "Supervised learning with quantum-enhanced feature spaces," *Nature* 567, 209–212 (2019)

# %%
@qml.qnode(dev_braket_local)
def circuit_zz_feature_map(x, reps=2):
    for _ in range(reps):
        for i in range(N_QUBITS):
            qml.Hadamard(wires=i)
        
        for i in range(N_QUBITS):
            qml.RZ(x[i], wires=i)
        
        # ZZ entangling — same operation, one gate instead of three
        for i in range(N_QUBITS):
            for j in range(i + 1, N_QUBITS):
                qml.IsingZZ(x[i] * x[j], wires=[i, j]) # angle is phi/2
    
    single = [qml.expval(qml.PauliZ(i)) for i in range(N_QUBITS)]
    pairs = [
        qml.expval(qml.PauliZ(i) @ qml.PauliZ(j))
        for i in range(N_QUBITS) for j in range(i + 1, N_QUBITS)
    ]
    return single + pairs

# %% [markdown]
# #### 5.3 IQP (Instantaneous Quantum Polynomial) Encoding
#
# - **What it does**: A diagonal circuit (all gates commute) that applies Hadamards, encodes feature products via diagonal phase gates, then Hadamards again.
# - **Key idea**: The resulting output distribution is believed to be classically hard to sample from, suggesting the feature space is genuinely beyond the reach of classical polynomial kernels. Same depth as ZZ map but a different algebraic structure.
# - **Paper**: Shepherd & Bremner, "Temporally Unstructured Quantum Computation," *Proc. Royal Society A* (2009); applied to ML in Havlíček et al. (2019)
#
# Pennylane IQP: [link](https://docs.pennylane.ai/en/stable/code/api/pennylane.IQPEmbedding.html)

# %%
@qml.qnode(dev_braket_local)
def circuit_iqp(x, reps=2):
    for _ in range(reps):
        for i in range(N_QUBITS):
            qml.Hadamard(wires=i)
        
        for i in range(N_QUBITS):
            qml.RZ(x[i], wires=i)
        
        for i in range(N_QUBITS):
            for j in range(i + 1, N_QUBITS):
                qml.CNOT(wires=[i, j])
                qml.RZ(x[i] * x[j], wires=j)
                qml.CNOT(wires=[i, j])
    
    # THIS is what makes IQP different from ZZ
    for i in range(N_QUBITS):
        qml.Hadamard(wires=i)
    
    single = [qml.expval(qml.PauliZ(i)) for i in range(N_QUBITS)]
    pairs = [
        qml.expval(qml.PauliZ(i) @ qml.PauliZ(j))
        for i in range(N_QUBITS) for j in range(i + 1, N_QUBITS)
    ]
    return single + pairs

# %% [markdown]
# Experimenting with hyperparamters for zz_feature_map

# %%
dev_zz = qml.device("default.qubit", wires=N_QUBITS)

@qml.qnode(dev_zz)
def circuit_zz_tunable(x, reps, scale):
    for _ in range(reps):
        for i in range(N_QUBITS):
            qml.Hadamard(wires=i)
        for i in range(N_QUBITS):
            qml.RZ(scale * x[i], wires=i)
        for i in range(N_QUBITS):
            for j in range(i + 1, N_QUBITS):
                qml.IsingZZ(scale * x[i] * x[j], wires=[i, j])
    
    single = [qml.expval(qml.PauliZ(i)) for i in range(N_QUBITS)]
    pairs = [
        qml.expval(qml.PauliZ(i) @ qml.PauliZ(j))
        for i in range(N_QUBITS) for j in range(i + 1, N_QUBITS)
    ]
    return single + pairs


def extract_zz_param_features(X, reps, scale, label="zz"):
    features = []
    for i, x in enumerate(X):
        result = circuit_zz_tunable(x, reps, scale)
        features.append(result)
        if (i + 1) % 200 == 0:
            print(f"  {label}: processed {i + 1}/{len(X)} samples")
    return np.array(features)
# Generate smaller dataset
X_full, y_full, regimes_full = generate_regime_data(1000, seed=42)

# Split into train, validation, test
X_temp, X_test, y_temp, y_test, reg_temp, reg_test = train_test_split(
    X_full, y_full, regimes_full, test_size=0.2, random_state=42
)
X_train, X_val, y_train, y_val, reg_train, reg_val = train_test_split(
    X_temp, y_temp, reg_temp, test_size=0.25, random_state=42
)

print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Should be roughly 600 / 200 / 200

# Preprocess
X_train_s, X_val_s, X_train_q, X_val_q, scaler = preprocess_features(X_train, X_val)
X_test_s = scaler.transform(X_test)
X_test_s = np.clip(X_test_s, -5.0, 5.0)
X_test_q = (X_test_s + 5.0) / 10.0 * np.pi

# Hyperparameter sweep — tune on validation, report on test
reps_list = [1, 2, 3, 4]
scale_list = [0.5, 1.0, 1.5, 2.0]
alpha_list = [0.01, 0.1, 1.0, 10.0]

sweep_results = []

for reps in reps_list:
    for scale in scale_list:
        print(f"\nExtracting: reps={reps}, scale={scale}")
        
        ZZ_tr = extract_zz_param_features(X_train_q, reps, scale, "train")
        ZZ_val = extract_zz_param_features(X_val_q, reps, scale, "val")
        
        X_tr = np.hstack([X_train_s, ZZ_tr])
        X_v = np.hstack([X_val_s, ZZ_val])
        scaler_aug = StandardScaler()
        X_tr = scaler_aug.fit_transform(X_tr)
        X_v = scaler_aug.transform(X_v)
        
        for alpha in alpha_list:
            ridge = Ridge(alpha=alpha).fit(X_tr, y_train)
            pred_val = ridge.predict(X_v)
            result = evaluate_model(y_val, pred_val,
                                    f"ZZ r={reps} s={scale} a={alpha}")
            sweep_results.append({
                **result,
                "reps": reps,
                "scale": scale,
                "alpha": alpha
            })

sweep_df = pd.DataFrame(sweep_results)
print("\n=== Validation Results (Top 10) ===")
print(sweep_df.sort_values("MSE").head(10).to_string(index=False))

# Take best hyperparameters, evaluate ONCE on test set
best = sweep_df.sort_values("MSE").iloc[0]
best_reps = int(best["reps"])
best_scale = float(best["scale"])
best_alpha = float(best["alpha"])
print(f"\nBest params: reps={best_reps}, scale={best_scale}, alpha={best_alpha}")

# Final evaluation on held-out test set
ZZ_tr_final = extract_zz_param_features(X_train_q, best_reps, best_scale, "train")
ZZ_te_final = extract_zz_param_features(X_test_q, best_reps, best_scale, "test")

X_tr_final = np.hstack([X_train_s, ZZ_tr_final])
X_te_final = np.hstack([X_test_s, ZZ_te_final])
scaler_final = StandardScaler()
X_tr_final = scaler_final.fit_transform(X_tr_final)
X_te_final = scaler_final.transform(X_te_final)

ridge_final = Ridge(alpha=best_alpha).fit(X_tr_final, y_train)
pred_test = ridge_final.predict(X_te_final)
print("\n=== Final Test Set Result ===")
print(evaluate_model(y_test, pred_test, f"ZZ (best params)"))
# Out:
# Train: 600, Val: 200, Test: 200
#
# Extracting: reps=1, scale=0.5
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=1, scale=1.0
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=1, scale=1.5
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=1, scale=2.0
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=2, scale=0.5
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=2, scale=1.0
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=2, scale=1.5
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=2, scale=2.0
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=3, scale=0.5
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=3, scale=1.0
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=3, scale=1.5
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=3, scale=2.0
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=4, scale=0.5
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=4, scale=1.0
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=4, scale=1.5
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# Extracting: reps=4, scale=2.0
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   val: processed 200/200 samples
#
# === Validation Results (Top 10) ===
#               model      MSE      MAE   Corr  reps  scale  alpha
# ZZ r=3 s=0.5 a=0.01 2.439403 1.193667 0.9612     3    0.5   0.01
#  ZZ r=3 s=0.5 a=0.1 2.441520 1.194239 0.9612     3    0.5   0.10
#  ZZ r=3 s=0.5 a=1.0 2.462144 1.199593 0.9609     3    0.5   1.00
# ZZ r=3 s=0.5 a=10.0 2.611982 1.237103 0.9586     3    0.5  10.00
#  ZZ r=3 s=1.0 a=1.0 2.829609 1.304538 0.9547     3    1.0   1.00
#  ZZ r=3 s=1.0 a=0.1 2.841928 1.309406 0.9545     3    1.0   0.10
# ZZ r=3 s=1.0 a=0.01 2.843530 1.309936 0.9545     3    1.0   0.01
# ZZ r=3 s=1.0 a=10.0 2.846521 1.304964 0.9548     3    1.0  10.00
# ZZ r=2 s=0.5 a=0.01 3.256257 1.370671 0.9475     2    0.5   0.01
#  ZZ r=2 s=0.5 a=0.1 3.256595 1.370701 0.9475     2    0.5   0.10
#
# Best params: reps=3, scale=0.5, alpha=0.01
#   train: processed 200/600 samples
#   train: processed 400/600 samples
#   train: processed 600/600 samples
#   test: processed 200/200 samples
#
# === Final Test Set Result ===
# {'model': 'ZZ (best params)', 'MSE': 2.147155, 'MAE': 1.159912, 'Corr': np.float64(0.9788)}

# %%
print("Best params", best_reps, best_scale, best_alpha)
# Out:
# Best params 3 0.5 0.01

# %%
# TODO — Experiment with different feature maps and parameters
#
# Ideas to try (following is just for ideas and not a requirement):
# 1. Change the number of reps in zz_feature_map (reps=1, 2, 3)
# 2. Use iqp_encoding instead of zz_feature_map
# 3. Try 'probability' extraction instead of 'expectation'
# 4. Use varying number of qubits (e.g., 3, 10, 15) and see how it affects performance
# 5. Try Combine quantum features with polynomial classical features

# %%
# --- ZZ Feature Map ---
print("\n=== ZZ Feature Map ===")

def extract_zz_features(X, reps=2, label="zz"):
    features = []
    for i, x in enumerate(X):
        result = circuit_zz_feature_map(x, reps=reps)
        features.append(result)
        if (i + 1) % 500 == 0:
            print(f"  {label}: processed {i + 1}/{len(X)} samples")
    return np.array(features)

ZZ_train = extract_zz_features(X_train_q, reps=2, label="zz train")
ZZ_test = extract_zz_features(X_test_q, reps=2, label="zz test")
# Out:
# === ZZ Feature Map ===
# KeyboardInterrupt

# %%
# --- IQP ---
print("\n=== IQP ===")

def extract_iqp_features(X, reps=2, label="iqp"):
    features = []
    for i, x in enumerate(X):
        result = circuit_iqp(x, reps=reps)
        features.append(result)
        if (i + 1) % 500 == 0:
            print(f"  {label}: processed {i + 1}/{len(X)} samples")
    return np.array(features)

IQP_train = extract_iqp_features(X_train_q, reps=2, label="iqp train")
IQP_test = extract_iqp_features(X_test_q, reps=2, label="iqp test")

# %%
# --- Combine, standardize, evaluate ---
print("\n=== Evaluation ===")

results_feature_maps = []

# Quantum: Angle Encoding
X_tr_a = np.hstack([X_train_s, Q_train_angle])
X_te_a = np.hstack([X_test_s, Q_test_angle])
scaler_a = StandardScaler()
X_tr_a = scaler_a.fit_transform(X_tr_a)
X_te_a = scaler_a.transform(X_te_a)

ridge_a = Ridge(alpha=1.0).fit(X_tr_a, y_train)
results_feature_maps.append(evaluate_model(y_test, ridge_a.predict(X_te_a), "Ridge (raw + Angle)"))
lasso_a = Lasso(alpha=0.01).fit(X_tr_a, y_train)
results_feature_maps.append(evaluate_model(y_test, lasso_a.predict(X_te_a), "Lasso (raw + Angle)"))


# Quantum: ZZ
X_tr_z = np.hstack([X_train_s, ZZ_train])
X_te_z = np.hstack([X_test_s, ZZ_test])
scaler_z = StandardScaler()
X_tr_z = scaler_z.fit_transform(X_tr_z)
X_te_z = scaler_z.transform(X_te_z)

ridge_z = Ridge(alpha=1.0).fit(X_tr_z, y_train)
results_feature_maps.append(evaluate_model(y_test, ridge_z.predict(X_te_z), "Ridge (raw + ZZ)"))
lasso_z = Lasso(alpha=0.01).fit(X_tr_z, y_train)
results_feature_maps.append(evaluate_model(y_test, lasso_z.predict(X_te_z), "Lasso (raw + ZZ)"))

# Quantum: IQP
X_tr_i = np.hstack([X_train_s, IQP_train])
X_te_i = np.hstack([X_test_s, IQP_test])
scaler_i = StandardScaler()
X_tr_i = scaler_i.fit_transform(X_tr_i)
X_te_i = scaler_i.transform(X_te_i)

ridge_i = Ridge(alpha=1.0).fit(X_tr_i, y_train)
results_feature_maps.append(evaluate_model(y_test, ridge_i.predict(X_te_i), "Ridge (raw + IQP)"))
lasso_i = Lasso(alpha=0.01).fit(X_tr_i, y_train)
results_feature_maps.append(evaluate_model(y_test, lasso_i.predict(X_te_i), "Lasso (raw + IQP)"))

# Print comparison
results_df = pd.DataFrame(results_feature_maps)
print("\n=== Full Comparison (Out-of-Sample) ===")
print(results_df.to_string(index=False))

print("\n=== Classical Baselines (Out-of-Sample) ===")
print(baseline_df.to_string(index=False))

# %%
results_df

# %% [markdown]
# ## 6. Hybrid Quantum-Classical Workflows
#
# In the previous sections, quantum circuits were fixed - no trainable parameters. In hybrid workflows we add **variational parameters**: gate angles optimized via classical gradient descent, just like weights in a neural network.
#
# The intended use for the requirement of utilizing a linear regression model would be trainining your hybrid tranformer to produce augmented features that are produced by the circuit according to a valid/relevant objective. Varitional Quantum Circuits can also result in being their own autonomous predictors, feel free to experiment with it after meeting the regression model requirement for comparisons as in the handout.
#
# #### 6.1 Variational Quantum Circuit (VQC) as Feature Transformer
#
# - **What it does**: A parameterized circuit where some gate angles encode input data and others are *trainable*. The circuit's expectation values serve as a learned feature transformation.
# - **Key idea**: Alternating data-encoding layers and variational layers let the circuit *adapt* its feature extraction to the task. Think of it as a quantum neural network layer that learns which features to pull out of the Hilbert space.
# - **Paper**: Mitarai et al., "Quantum Circuit Learning," *PRA* 98, 032309 (2018)

# %%
n_layers = 2

dev_var = qml.device("default.qubit", wires=N_QUBITS)

@qml.qnode(dev_var, diff_method="parameter-shift")
def variational_circuit(x, weights):
    """
    Alternating data encoding and trainable rotation layers.
    
    Args:
        x: input features, shape (4,)
        weights: trainable params, shape (n_layers, N_QUBITS, 3)
    """
    for layer in range(weights.shape[0]):
        # Data encoding
        for i in range(N_QUBITS):
            qml.RY(x[i], wires=i)
        
        # Trainable rotations (3 per qubit for full rotational freedom)
        for i in range(N_QUBITS):
            qml.RX(weights[layer, i, 0], wires=i)
            qml.RY(weights[layer, i, 1], wires=i)
            qml.RZ(weights[layer, i, 2], wires=i)
        
        # Entanglement
        for i in range(N_QUBITS):
            qml.CNOT(wires=[i, (i + 1) % N_QUBITS])
    
    single = [qml.expval(qml.PauliZ(i)) for i in range(N_QUBITS)]
    pairs = [
        qml.expval(qml.PauliZ(i) @ qml.PauliZ(j))
        for i in range(N_QUBITS) for j in range(i + 1, N_QUBITS)
    ]
    return single + pairs


def get_quantum_features(X, weights):
    """Extract quantum features for a batch."""
    features = []
    for x in X:
        result = variational_circuit(x, weights)
        features.append(result)
    return pnp.array(features, requires_grad=False)


def cost_fn(weights, linear_weights, X_batch, y_batch):
    """
    End-to-end loss with differentiable linear layer.
    """
    q_features = get_quantum_features(X_batch, weights)
    full_features = pnp.hstack([X_batch, q_features])
    
    # Differentiable linear prediction instead of lstsq
    predictions = full_features @ linear_weights
    
    mse = pnp.mean((y_batch - predictions) ** 2)
    return mse


# Initialize
weights = pnp.random.uniform(0, 2 * np.pi, size=(n_layers, N_QUBITS, 3), requires_grad=True)

# Linear weights: 4 original features + 10 quantum features = 14
n_features = N_QUBITS + 10  # 4 raw + 4 single-qubit + 6 pairwise
linear_weights = pnp.random.uniform(-0.1, 0.1, size=(n_features,), requires_grad=True)

train_size = 300
X_batch = pnp.array(X_train_q[:train_size], requires_grad=False)
y_batch = pnp.array(y_train[:train_size], requires_grad=False)

opt = qml.AdamOptimizer(stepsize=0.05)
n_epochs = 30

print("Training variational circuit...")
losses = []
for epoch in range(n_epochs):
    (weights, linear_weights), cost = opt.step_and_cost(
        lambda w, lw: cost_fn(w, lw, X_batch, y_batch),
        weights, linear_weights
    )
    losses.append(float(cost))
    if (epoch + 1) % 5 == 0:
        print(f"  Epoch {epoch + 1}/{n_epochs}, Loss: {cost:.4f}")

print("Training complete!")

# %%
# -- Phase 1 complete: VQC weights trained end-to-end in cell above -----------
# Plot training loss curve
plt.figure(figsize=(7, 3))
plt.plot(losses, marker="o", markersize=3, linewidth=1.5, color="steelblue")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("VQC End-to-End Training Loss (Phase 1)")
plt.tight_layout()
plt.show()

# -- Phase 2: Freeze weights, extract features, fit Ridge regression ----------
# Use trained weights in inference mode (no gradients needed)
weights_frozen = pnp.array(weights, requires_grad=False)

print("Extracting VQC features (train)...")
VQC_train = []
for i, x in enumerate(X_train_q):
    result = variational_circuit(pnp.array(x, requires_grad=False), weights_frozen)
    VQC_train.append(np.array(result))
    if (i + 1) % 200 == 0:
        print(f"  {i + 1}/{len(X_train_q)}")
VQC_train = np.array(VQC_train)

print("Extracting VQC features (test)...")
VQC_test = []
for i, x in enumerate(X_test_q):
    result = variational_circuit(pnp.array(x, requires_grad=False), weights_frozen)
    VQC_test.append(np.array(result))
    if (i + 1) % 100 == 0:
        print(f"  {i + 1}/{len(X_test_q)}")
VQC_test = np.array(VQC_test)

# %%
# Each sample: 4 single-qubit <Z_i> + 6 pairwise <Z_i Z_j> = 10 features
print(f"VQC feature shape -- train: {VQC_train.shape}, test: {VQC_test.shape}")

# -- Combine raw standardized features + VQC features ------------------------
X_tr_vqc = np.hstack([X_train_s, VQC_train])
X_te_vqc  = np.hstack([X_test_s,  VQC_test])

scaler_vqc = StandardScaler()
X_tr_vqc = scaler_vqc.fit_transform(X_tr_vqc)
X_te_vqc  = scaler_vqc.transform(X_te_vqc)

ridge_vqc = Ridge(alpha=1.0).fit(X_tr_vqc, y_train)
pred_vqc  = ridge_vqc.predict(X_te_vqc)

lasso_vqc = Lasso(alpha=0.01).fit(X_tr_vqc, y_train)
pred_vqc_lasso = lasso_vqc.predict(X_te_vqc)

vqc_result_ridge = evaluate_model(y_test, pred_vqc, "Ridge (raw + VQC)")
vqc_result_lasso = evaluate_model(y_test, pred_vqc_lasso, "Lasso (raw + VQC)")

# -- Full comparison ----------------------------------------------------------
results_vqc_df = pd.concat(
    [results_df, pd.DataFrame([vqc_result_ridge, vqc_result_lasso])],
    ignore_index=True
).sort_values("MSE").reset_index(drop=True)

# check the number of features that lasso kept non-zero
n_nonzero = np.sum(lasso_vqc.coef_ != 0)
print(f"\nLasso selected {n_nonzero} features out of {X_tr_vqc.shape[1]} total features.")
results_vqc_df

# %%
baseline_df.sort_values("MSE").reset_index(drop=True)

# %% [markdown]
# #### 6.2 Quantum Reservoir Computing
#
# - **What it does**: Uses a *random*, untrained quantum circuit as a fixed nonlinear feature extractor. Only the classical readout layer is trained.
# - **Key idea**: Analogous to classical echo-state networks - the quantum circuit provides a rich, high-dimensional nonlinear transformation without needing gradient-based optimization. Different random seeds give different feature spaces; you can ensemble multiple reservoirs cheaply.
# - **Paper**: Fujii & Nakajima, "Harnessing Disordered-Ensemble Quantum Dynamics for Machine Learning," *PRA* 96, 042306 (2017)

# %%
# Experiment with hybrid workflows
#
# Ideas to try:
# 1. Train VQC with more epochs and larger training set
# 2. Change VQC architecture: more layers, different entangling patterns
# 3. Vary reservoir parameters: n_layers, n_reservoirs, different seeds
# 4. Combine reservoir features with quantum kernel (use reservoir features as
#    input to a classical RBF kernel)
# NOTE: These are to guide your ideas, and not restrain your implementation. We are looking for rigorous comparisons, you can be creative with your feature engineering approach as you like

# %%
# Quantum Reservoir Computing
# Multiple random circuits as fixed feature extractors

def create_reservoir_circuit(n_qubits, seed):
    """Create a random reservoir circuit with a unique seed."""
    rng = np.random.default_rng(seed)
    
    dev_res = qml.device("default.qubit", wires=n_qubits)
    
    # Random fixed parameters
    n_layers = 3
    random_weights = pnp.array(
        rng.uniform(0, 2 * np.pi, size=(n_layers, n_qubits, 3)),
        requires_grad=False
    )
    
    @qml.qnode(dev_res)
    def reservoir(x):
        for layer in range(n_layers):
            # Encode data
            for i in range(n_qubits):
                qml.RY(x[i % len(x)], wires=i)
            
            # Random fixed rotations
            for i in range(n_qubits):
                qml.RX(random_weights[layer, i, 0], wires=i)
                qml.RY(random_weights[layer, i, 1], wires=i)
                qml.RZ(random_weights[layer, i, 2], wires=i)
            
            # Entanglement
            for i in range(n_qubits):
                qml.CNOT(wires=[i, (i + 1) % n_qubits])
        
        single = [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]
        pairs = [
            qml.expval(qml.PauliZ(i) @ qml.PauliZ(j))
            for i in range(n_qubits) for j in range(i + 1, n_qubits)
        ]
        return single + pairs
    
    return reservoir


def extract_reservoir_features(X, n_reservoirs=3, n_qubits=4, label="reservoir"):
    """
    Run data through multiple random reservoir circuits
    and concatenate all their features.
    """
    # Create multiple reservoirs with different random seeds
    reservoirs = [create_reservoir_circuit(n_qubits, seed=s) for s in range(n_reservoirs)]
    
    all_features = []
    for i, x in enumerate(X):
        sample_features = []
        for res in reservoirs:
            result = res(x)
            sample_features.extend(result)
        all_features.append(sample_features)
        if (i + 1) % 500 == 0:
            print(f"  {label}: processed {i + 1}/{len(X)} samples")
    
    return np.array(all_features)


# Extract reservoir features
print("Extracting reservoir features (3 reservoirs)...")
RES_train = extract_reservoir_features(X_train_q, n_reservoirs=3, label="res train")
RES_test = extract_reservoir_features(X_test_q, n_reservoirs=3, label="res test")

print(f"Reservoir features shape: {RES_train.shape}")
# Should be (10000, 30) — 10 features per reservoir × 3 reservoirs
results_reservoir = []
# Combine, standardize, evaluate
X_tr_r = np.hstack([X_train_s, RES_train])
X_te_r = np.hstack([X_test_s, RES_test])
scaler_r = StandardScaler()
X_tr_r = scaler_r.fit_transform(X_tr_r)
X_te_r = scaler_r.transform(X_te_r)

ridge_r = Ridge(alpha=1.0).fit(X_tr_r, y_train)
pred_r = ridge_r.predict(X_te_r)
results_reservoir.append(evaluate_model(y_test, pred_r, "Ridge (raw + Reservoir x3)"))

# Also try Lasso to see which features matter
lasso_r = Lasso(alpha=0.01).fit(X_tr_r, y_train)
pred_lasso_r = lasso_r.predict(X_te_r)
results_reservoir.append(evaluate_model(y_test, pred_lasso_r, "Lasso (raw + Reservoir x3)"))
# Out:
# Extracting reservoir features (3 reservoirs)...
#   res train: processed 500/600 samples
# Reservoir features shape: (600, 30)

# %%
# Per-regime evaluation
for regime in [0, 1]:
    mask = regimes_test == regime
    regime_name = "Regime 1 (linear)" if regime == 0 else "Regime 2 (nonlinear)"
    n_samples = mask.sum()
    
    print(f"\n=== {regime_name} ({n_samples} samples) ===")
    
    # Classical baselines
    pred_raw = lr_raw.predict(X_test_s)
    print(evaluate_model(y_test[mask], pred_raw[mask], "LR (raw)"))
    
    pred_poly = ridge_poly.predict(X_test_poly)
    print(evaluate_model(y_test[mask], pred_poly[mask], "Ridge (poly deg=2)"))
    
    # Reservoir
    pred_res = ridge_r.predict(X_te_r)
    print(evaluate_model(y_test[mask], pred_res[mask], "Ridge (reservoir)"))
    
    pred_lasso_res = lasso_r.predict(X_te_r)
    print(evaluate_model(y_test[mask], pred_lasso_res[mask], "Lasso (reservoir)"))
# Out:
# === Regime 1 (linear) (7633 samples) ===
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 11
#       7     print(f"\n=== {regime_name} ({n_samples} samples) ===")
#       8
#       9     # Classical baselines
#      10     pred_raw = lr_raw.predict(X_test_s)
# ---> 11     print(evaluate_model(y_test[mask], pred_raw[mask], "LR (raw)"))
#      12
#      13     pred_poly = ridge_poly.predict(X_test_poly)
#      14     print(evaluate_model(y_test[mask], pred_poly[mask], "Ridge (poly deg=2)"))
#
# IndexError: boolean index did not match indexed array along axis 0; size of axis is 200 but size of corresponding boolean axis is 10000

# %%
results_reservoir_df = pd.DataFrame(results_reservoir)
print("\n=== Reservoir Results ===")
results_reservoir_df.sort_values("MSE").reset_index(drop=True)

# %%
baseline_df.sort_values("MSE").reset_index(drop=True)

# %% [markdown]
# ### Extracting Features from Quantum States
#
# Once data is encoded into a quantum state, we need to *extract* quantum-augmented features from it. Two main approaches:
#
# 1. **Expectation values**: Measure observables (Pauli-Z, X, Y or products) on each qubit. Each gives a real number in [-1, 1]. With *n* qubits you get *n* features per observable type.
#
# 2. **Probabilities**: Measure the probability of each computational basis state. With *n* qubits this gives 2ⁿ features (exponential — potentially richer but expensive). n qubits will result in 2ⁿ features, which could lead to overfitting in the regression model

# %% [markdown]
# ## 8. Dimensionality Reduction
# To deal with overfitting after augmented features, you can also employ dimensionality reduction tools within your model/circuit (Regularization).

# %% [markdown]
# ## 9. Evaluation
# Collect results from your implemented methods and visualize side-by-side. Remember: the challenge values **rigorous out-of-sample evaluation** over raw performance numbers.

# %% [markdown]
# ## 10. Real World Scenario - Adapting to Real Stock Data
#
# The second task requires you to work with **actual S&P 500 data**. Refer the challenge handout
#
# NOTE: Make sure there is no data leaks between training and testing data when implementing Walk-forward backtesting.

# %%
import yfinance as yf
import pandas as pd
import numpy as np

# Top 10 S&P 500 stocks by market cap
tickers = ["AAPL", "MSFT", "NVDA", "AMZN", "GOOGL", "META", "BRK-B", "LLY", "AVGO", "JPM"]
market_ticker = "^GSPC"  # S&P 500 index

# Download data — 5 years gives ~4 years training + ~1 year test
start_date = "2020-01-01"  
end_date = "2025-01-01"

print("Downloading stock data...")
# Re-download with explicit structure
stock_data = yf.download(tickers, start=start_date, end=end_date, auto_adjust=True, group_by="ticker")
market_data = yf.download(market_ticker, start=start_date, end=end_date, auto_adjust=True)

# Market data might have a MultiIndex even for a single ticker
# Flatten it if needed
if isinstance(market_data.columns, pd.MultiIndex):
    market_data.columns = market_data.columns.droplevel("Ticker")

print("Stock columns:", stock_data.columns[:5])
print("Market columns:", market_data.columns)
# Out:
# Downloading stock data...
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  1 of 1 completed
# Stock columns: MultiIndex([('NVDA',   'Open'),
#             ('NVDA',   'High'),
#             ('NVDA',    'Low'),
#             ('NVDA',  'Close'),
#             ('NVDA', 'Volume')],
#            names=['Ticker', 'Price'])
# Market columns: Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %%
def compute_features(stock_df, market_df, ticker):
    # Extract single stock data
    s = stock_df[ticker]  # with group_by="ticker", this gives a clean DataFrame
    m = market_df
    
    # Make sure these are Series, not DataFrames
    s_close = s["Close"].squeeze()
    m_close = m["Close"].squeeze()
    s_high = s["High"].squeeze()
    m_high = m["High"].squeeze()
    s_low = s["Low"].squeeze()
    m_low = m["Low"].squeeze()
    s_volume = s["Volume"].squeeze()
    m_volume = m["Volume"].squeeze()
    
    features = pd.DataFrame(index=s.index)
    
    # Target
    stock_5d_ret = s_close.pct_change(5).shift(-5)
    market_5d_ret = m_close.pct_change(5).shift(-5)
    features["target"] = stock_5d_ret - market_5d_ret
    
    # Prior returns
    features["ret_5d"] = s_close.pct_change(5) - m_close.pct_change(5)
    features["ret_20d"] = s_close.pct_change(20) - m_close.pct_change(20)
    features["ret_120d"] = s_close.pct_change(120) - m_close.pct_change(120)
    
    # Max/min price ratio
    s_max20 = s_high.rolling(20).max() / s_close - 1
    m_max20 = m_high.rolling(20).max() / m_close - 1
    features["max_price_ratio_20d"] = s_max20 - m_max20
    
    s_min20 = s_low.rolling(20).min() / s_close - 1
    m_min20 = m_low.rolling(20).min() / m_close - 1
    features["min_price_ratio_20d"] = s_min20 - m_min20
    
    # RSI
    def compute_rsi(close, period=10):
        delta = close.diff()
        gain = delta.where(delta > 0, 0).rolling(period).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(period).mean()
        rs = gain / (loss + 1e-10)
        return 100 - 100 / (1 + rs)
    
    features["rsi_10d"] = compute_rsi(s_close) - compute_rsi(m_close)
    
    # Price trend
    s_trend = s_close.rolling(10).mean() / s_close.rolling(50).mean() - 1
    m_trend = m_close.rolling(10).mean() / m_close.rolling(50).mean() - 1
    features["price_trend"] = s_trend - m_trend
    
    # Volume z-score
    def zscore_vol(vol, window):
        return (vol.rolling(window).mean() - vol.rolling(120).mean()) / (vol.rolling(120).std() + 1e-10)
    
    features["vol_zscore_5d"] = zscore_vol(s_volume, 5) - zscore_vol(m_volume, 5)
    features["vol_zscore_20d"] = zscore_vol(s_volume, 20) - zscore_vol(m_volume, 20)
    
    # Volume trend
    s_vol_trend = s_volume.rolling(10).mean() / s_volume.rolling(50).mean() - 1
    m_vol_trend = m_volume.rolling(10).mean() / m_volume.rolling(50).mean() - 1
    features["vol_trend"] = s_vol_trend - m_vol_trend
    
    # Volume-weighted return
    def vw_return(close, volume, window=5):
        ret = close.pct_change()
        w = volume / volume.rolling(window).sum()
        return (ret * w).rolling(window).sum()
    
    features["vw_return_5d"] = vw_return(s_close, s_volume) - vw_return(m_close, m_volume)
    
    # RSI × volume z-score
    features["rsi_x_vol"] = (compute_rsi(s_close) * zscore_vol(s_volume, 5)) - \
                             (compute_rsi(m_close) * zscore_vol(m_volume, 5))
    
    # Volume trend - price trend
    features["vol_minus_price_trend"] = features["vol_trend"] - features["price_trend"]
    
    features["ticker"] = ticker
    
    return features

features_df = compute_features(stock_data, market_data, tickers[0])

# %%
feature_cols = [c for c in features_df.columns if c not in ["target", "ticker"]]

print(f"Samples: {len(features_df)}")
print(f"Date range: {features_df.index.min()} to {features_df.index.max()}")
print(f"Features: {len(feature_cols)}")
print(f"\nTarget stats:")
print(features_df["target"].describe())
print(f"\nFeature stats:")
print(features_df[feature_cols].describe().round(4))

# Check for any remaining NaN or inf
print(f"\nNaN count: {features_df[feature_cols].isna().sum().sum()}")
print(f"Inf count: {np.isinf(features_df[feature_cols].values).sum()}")
# Out:
# Samples: 1258
# Date range: 2020-01-02 00:00:00 to 2024-12-31 00:00:00
# Features: 13
#
# Target stats:
# count    1253.000000
# mean        0.003042
# std         0.027773
# min        -0.089445
# 25%        -0.012110
# 50%         0.000834
# 75%         0.018944
# max         0.152430
# Name: target, dtype: float64
#
# Feature stats:
#           ret_5d    ret_20d   ret_120d  max_price_ratio_20d  \
# count  1253.0000  1238.0000  1138.0000            1239.0000
# mean      0.0030     0.0116     0.0689               0.0243
# std       0.0278     0.0571     0.1607               0.0350
# min      -0.0894    -0.1680    -0.2578              -0.0971
# 25%      -0.0121    -0.0248    -0.0424               0.0022
# 50%       0.0008     0.0063     0.0485               0.0164
# 75%       0.0189     0.0448     0.1638               0.0423
# max       0.1524     0.2888     0.7503               0.2105
#
#        min_price_ratio_20d    rsi_10d  price_trend  vol_zscore_5d  \
# count            1239.0000  1249.0000    1209.0000      1139.0000
# mean               -0.0273    -1.4358       0.0096        -0.0942
# std                 0.0352    15.4730       0.0420         0.7441
# min                -0.1948   -60.5012      -0.0968        -2.5112
# 25%                -0.0477   -10.6339      -0.0173        -0.5058
# 50%                -0.0210    -0.9290       0.0084        -0.1134
# 75%                -0.0026     8.4545       0.0365         0.3155
# max                 0.0632    52.2944       0.1401         3.0055
#
#        vol_zscore_20d  vol_trend  vw_return_5d  rsi_x_vol  \
# count       1139.0000  1209.0000     1250.0000  1139.0000
# mean          -0.0814    -0.0196        0.0007    -4.2483
# std            0.5444     0.1637        0.0079    45.6485
# min           -1.6043    -0.4451       -0.0260  -156.4248
# 25%           -0.4020    -0.1308       -0.0031   -28.8441
# 50%           -0.0617    -0.0346        0.0000    -5.4348
# 75%            0.2447     0.0792        0.0045    14.7707
# max            1.7059     0.6828        0.0548   251.9182
#
#        vol_minus_price_trend
# count              1209.0000
# mean                 -0.0292
# std                   0.1601
# min                  -0.4296
# 25%                  -0.1496
# 50%                  -0.0422
# 75%                   0.0792
# max                   0.6021
#
# NaN count: 704
# Inf count: 0

# %%
# Check NaN count per feature
print("NaN per feature:")
print(features_df[feature_cols].isna().sum().sort_values(ascending=False))

# Show which rows have NaN and what the earliest valid date is per feature
print("\nFirst valid date per feature:")
for col in feature_cols:
    first_valid = features_df[col].first_valid_index()
    print(f"  {col}: {first_valid}")

# Show a sample of rows with NaN
nan_rows = features_df[features_df[feature_cols].isna().any(axis=1)]
print(f"\nRows with NaN: {len(nan_rows)}")
print(f"Date range of NaN rows: {nan_rows.index.min()} to {nan_rows.index.max()}")
print(f"\nDate range of clean rows: {features_df.dropna().index.min()} to {features_df.dropna().index.max()}")

features_df_clean = features_df.dropna()
# Out:
# NaN per feature:
# ret_120d                 120
# vol_zscore_5d            119
# rsi_x_vol                119
# vol_zscore_20d           119
# price_trend               49
# vol_minus_price_trend     49
# vol_trend                 49
# ret_20d                   20
# max_price_ratio_20d       19
# min_price_ratio_20d       19
# rsi_10d                    9
# vw_return_5d               8
# ret_5d                     5
# dtype: int64
#
# First valid date per feature:
#   ret_5d: 2020-01-09 00:00:00
#   ret_20d: 2020-01-31 00:00:00
#   ret_120d: 2020-06-24 00:00:00
#   max_price_ratio_20d: 2020-01-30 00:00:00
#   min_price_ratio_20d: 2020-01-30 00:00:00
#   rsi_10d: 2020-01-15 00:00:00
#   price_trend: 2020-03-13 00:00:00
#   vol_zscore_5d: 2020-06-23 00:00:00
#   vol_zscore_20d: 2020-06-23 00:00:00
#   vol_trend: 2020-03-13 00:00:00
#   vw_return_5d: 2020-01-14 00:00:00
#   rsi_x_vol: 2020-06-23 00:00:00
#   vol_minus_price_trend: 2020-03-13 00:00:00
#
# Rows with NaN: 120
# Date range of NaN rows: 2020-01-02 00:00:00 to 2020-06-23 00:00:00
#
# Date range of clean rows: 2020-06-24 00:00:00 to 2024-12-23 00:00:00

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler

# --- 1. DATA PREPARATION ---
print("Cleaning data...")
features_df_clean = features_df_clean.dropna()

feature_cols = [c for c in features_df_clean.columns if c not in ["target", "ticker"]]
numeric_features = features_df_clean[feature_cols].copy()
target_series = features_df_clean["target"].copy()

print(f"Using {len(feature_cols)} raw features directly with 13 qubits.")
print("Feature columns:", feature_cols)

experiment_datasets = {}

# --- 2. CLASSICAL BASELINES ---
print("Saving Classical Baselines...")
experiment_datasets["Classical_Baseline"] = numeric_features.copy()

# Standardize the 13 raw features, then map them to [0, pi] for quantum input.
# This keeps the same overall preprocessing logic as the earlier 4-qubit workflow,
# but now uses all 13 raw features directly instead of PCA(4).
scaler_13 = StandardScaler()
X_13_scaled = scaler_13.fit_transform(numeric_features.values)
X_13_clipped = np.clip(X_13_scaled, -5.0, 5.0)
X_13_q = (X_13_clipped + 5.0) / 10.0 * np.pi

experiment_datasets["Raw13_Baseline"] = pd.DataFrame(
    X_13_scaled, index=numeric_features.index, columns=feature_cols
)

N_QUBITS_STOCK = len(feature_cols)
assert N_QUBITS_STOCK == 13, f"Expected 13 raw features, got {N_QUBITS_STOCK}"

# --- 3. RESERVOIR (13-qubit direct version) ---
print("Generating Raw13 + Reservoir...")
reservoir_qnode = create_reservoir_circuit(n_qubits=N_QUBITS_STOCK, seed=42)
X_q_reservoir = np.array([
    reservoir_qnode(x) for x in tqdm(X_13_q, desc="Reservoir-13Q")
])
experiment_datasets["Raw13_Reservoir"] = pd.DataFrame(
    X_q_reservoir, index=numeric_features.index
)

# --- 4. GLOBAL PATCH + GLOBAL LQR CIRCUITS (13-qubit direct versions) ---
BANDWIDTHS_Q = [np.pi / 4, np.pi / 2, np.pi]
PATCH_DEPTH_Q = 4
LQR_DEPTH_Q = 8

np.random.seed(99)
_patch_ry = np.random.uniform(-np.pi, np.pi, (PATCH_DEPTH_Q, N_QUBITS_STOCK))
_patch_rz = np.random.uniform(-np.pi, np.pi, (PATCH_DEPTH_Q, N_QUBITS_STOCK))

np.random.seed(2026)
_lqr_rx = np.random.uniform(-np.pi, np.pi, (LQR_DEPTH_Q, N_QUBITS_STOCK))
_lqr_ry = np.random.uniform(-np.pi, np.pi, (LQR_DEPTH_Q, N_QUBITS_STOCK))
_lqr_rz = np.random.uniform(-np.pi, np.pi, (LQR_DEPTH_Q, N_QUBITS_STOCK))

_ENC_GATES = [qml.RX, qml.RY, qml.RZ]

def _itx(x, d):
    m = d % 3
    if m == 0:
        return x
    elif m == 1:
        return x * x
    else:
        return np.sin(x)

def _all_z_observables(n_qubits):
    single = [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]
    pairs = [
        qml.expval(qml.PauliZ(i) @ qml.PauliZ(j))
        for i in range(n_qubits) for j in range(i + 1, n_qubits)
    ]
    return single + pairs

def _make_global_patch_circuit(bw, n_qubits):
    dev_patch = qml.device("default.qubit", wires=n_qubits)

    @qml.qnode(dev_patch)
    def circuit(x):
        for d in range(PATCH_DEPTH_Q):
            # Fixed random local mixing
            for i in range(n_qubits):
                qml.RY(_patch_ry[d, i], wires=i)
                qml.RZ(_patch_rz[d, i], wires=i)

            # Ring entanglement
            for i in range(n_qubits):
                qml.CZ(wires=[i, (i + 1) % n_qubits])

            # Data re-uploading
            for i in range(n_qubits):
                qml.RZ(bw * x[i], wires=i)

        return _all_z_observables(n_qubits)

    return circuit

def _make_global_lqr_circuit(bw, n_qubits):
    dev_lqr = qml.device("default.qubit", wires=n_qubits)

    @qml.qnode(dev_lqr)
    def circuit(x):
        for d in range(LQR_DEPTH_Q):
            # Fixed random local scrambling
            for i in range(n_qubits):
                qml.RX(_lqr_rx[d, i], wires=i)
                qml.RY(_lqr_ry[d, i], wires=i)
                qml.RZ(_lqr_rz[d, i], wires=i)

            # Ring entanglement
            for i in range(n_qubits):
                qml.CZ(wires=[i, (i + 1) % n_qubits])

            # Nonlinear data encoding
            gate = _ENC_GATES[d % 3]
            for i in range(n_qubits):
                gate(bw * _itx(x[i], d), wires=i)

        return _all_z_observables(n_qubits)

    return circuit

patch_circuits = [_make_global_patch_circuit(bw, N_QUBITS_STOCK) for bw in BANDWIDTHS_Q]
lqr_circuits = [_make_global_lqr_circuit(bw, N_QUBITS_STOCK) for bw in BANDWIDTHS_Q]

def _run_global_family(X_q, circuits, label):
    rows = []
    for x in tqdm(X_q, desc=label):
        sample = []
        for circuit in circuits:
            sample.extend(np.array(circuit(x), dtype=float))
        rows.append(sample)
    return np.array(rows)

# --- 5. PATCH ---
print("Generating Raw13 + Global Patch Features...")
X_q_patch = _run_global_family(X_13_q, patch_circuits, "Patch-13Q")
experiment_datasets["Raw13_Patch"] = pd.DataFrame(
    X_q_patch, index=numeric_features.index
)

# --- 6. LQR ---
print("Generating Raw13 + Global LQR Features...")
X_q_lqr = _run_global_family(X_13_q, lqr_circuits, "LQR-13Q")
experiment_datasets["Raw13_LQR"] = pd.DataFrame(
    X_q_lqr, index=numeric_features.index
)

# --- 7. PATCH + LQR ---
print("Combining Patch + LQR...")
experiment_datasets["Raw13_Patch_LQR"] = pd.DataFrame(
    np.hstack([X_q_patch, X_q_lqr]), index=numeric_features.index
)

print(f"\n✅ {len(experiment_datasets)} experiments ready:")
for name, df in experiment_datasets.items():
    print(f"  {name}: {df.shape[1]} features")
# Out:
# Cleaning data...
# Using 13 raw features directly with 13 qubits.
# Feature columns: ['ret_5d', 'ret_20d', 'ret_120d', 'max_price_ratio_20d', 'min_price_ratio_20d', 'rsi_10d', 'price_trend', 'vol_zscore_5d', 'vol_zscore_20d', 'vol_trend', 'vw_return_5d', 'rsi_x_vol', 'vol_minus_price_trend']
# Saving Classical Baselines...
# Generating Raw13 + Reservoir...
# Reservoir-13Q: 100%|██████████| 1133/1133 [03:02<00:00,  6.21it/s]
# Generating Raw13 + Global Patch Features...
# Patch-13Q: 100%|██████████| 1133/1133 [07:07<00:00,  2.65it/s]
# Generating Raw13 + Global LQR Features...
# LQR-13Q: 100%|██████████| 1133/1133 [12:11<00:00,  1.55it/s]
# Combining Patch + LQR...
#
# ✅ 6 experiments ready:
#   Classical_Baseline: 13 features
#   Raw13_Baseline: 13 features
#   Raw13_Reservoir: 91 features
#   Raw13_Patch: 273 features
#   Raw13_LQR: 273 features
#   Raw13_Patch_LQR: 546 features

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


# ============================================================
# 1. Metric helper
# ============================================================
def compute_metrics(y_true, y_pred):
    y_true = np.asarray(y_true).reshape(-1)
    y_pred = np.asarray(y_pred).reshape(-1)

    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mse)

    if len(y_true) > 1 and np.std(y_true) > 1e-12 and np.std(y_pred) > 1e-12:
        corr = np.corrcoef(y_true, y_pred)[0, 1]
    else:
        corr = np.nan

    r2 = r2_score(y_true, y_pred)
    directional_acc = np.mean(np.sign(y_true) == np.sign(y_pred)) * 100
    bias = np.mean(y_pred - y_true)

    return {
        "MSE": mse,
        "MAE": mae,
        "RMSE": rmse,
        "Correlation": corr,
        "R2": r2,
        "Directional_Accuracy": directional_acc,
        "Bias": bias,
    }


# ============================================================
# 2. Full walk-forward backtest with per-fold diagnostics
# ============================================================
def diagnostic_walk_forward_backtest(X_df, y_series, train_window=504, horizon=5, alpha=1.0):
    """
    Rolling backtest that stores:
      - aggregate out-of-sample predictions
      - per-fold test metrics (for stability across time)
      - per-fold train metrics (for overfitting diagnostics)
    """
    y_aligned = y_series.loc[X_df.index]

    X = X_df.values
    y = y_aligned.values
    idx = X_df.index

    total_days = len(X)

    all_test_actuals = []
    all_test_preds = []

    fold_records = []

    for start in range(0, total_days - train_window - horizon + 1, 1):
        train_start = start
        train_end = start + train_window

        test_start = train_end
        test_end = train_end + horizon

        X_train = X[train_start:train_end]
        y_train = y[train_start:train_end]

        X_test = X[test_start:test_end]
        y_test = y[test_start:test_end]

        model = Ridge(alpha=alpha)
        model.fit(X_train, y_train)

        # Predictions
        train_preds = model.predict(X_train)
        test_preds = model.predict(X_test)

        # Save aggregate OOS predictions
        all_test_actuals.extend(y_test)
        all_test_preds.extend(test_preds)

        # Metrics for this fold
        train_metrics = compute_metrics(y_train, train_preds)
        test_metrics = compute_metrics(y_test, test_preds)

        fold_records.append({
            "fold": start,
            "test_end_date": idx[min(test_end - 1, len(idx) - 1)],
            "train_MSE": train_metrics["MSE"],
            "train_MAE": train_metrics["MAE"],
            "train_Correlation": train_metrics["Correlation"],
            "train_R2": train_metrics["R2"],
            "test_MSE": test_metrics["MSE"],
            "test_MAE": test_metrics["MAE"],
            "test_Correlation": test_metrics["Correlation"],
            "test_R2": test_metrics["R2"],
            "test_Directional_Accuracy": test_metrics["Directional_Accuracy"],
            "MSE_gap": test_metrics["MSE"] - train_metrics["MSE"],
            "MAE_gap": test_metrics["MAE"] - train_metrics["MAE"],
            "Corr_gap": (
                np.nan if np.isnan(train_metrics["Correlation"]) or np.isnan(test_metrics["Correlation"])
                else train_metrics["Correlation"] - test_metrics["Correlation"]
            ),
        })

    fold_df = pd.DataFrame(fold_records)
    all_test_actuals = np.array(all_test_actuals)
    all_test_preds = np.array(all_test_preds)

    return all_test_actuals, all_test_preds, fold_df


# ============================================================
# 3. Run experiments
# ============================================================
print("Running diagnostic backtests...\n")

target_series = features_df_clean["target"]

results_summary = {}
fold_results_by_experiment = {}
predictions_by_experiment = {}

for experiment_name, dataset_df in experiment_datasets.items():
    print(f"Evaluating: {experiment_name}")

    actuals, preds, fold_df = diagnostic_walk_forward_backtest(
        X_df=dataset_df,
        y_series=target_series,
        train_window=504,
        horizon=5,
        alpha=1.0
    )

    agg_metrics = compute_metrics(actuals, preds)

    # Performance stability across time
    stability_test_mse_std = fold_df["test_MSE"].std()
    stability_test_mae_std = fold_df["test_MAE"].std()
    stability_test_corr_std = fold_df["test_Correlation"].std()
    stability_test_mse_mean = fold_df["test_MSE"].mean()
    stability_test_mae_mean = fold_df["test_MAE"].mean()
    stability_test_corr_mean = fold_df["test_Correlation"].mean()

    # Overfitting diagnostics
    avg_train_mse = fold_df["train_MSE"].mean()
    avg_test_mse = fold_df["test_MSE"].mean()
    avg_train_mae = fold_df["train_MAE"].mean()
    avg_test_mae = fold_df["test_MAE"].mean()
    avg_train_corr = fold_df["train_Correlation"].mean()
    avg_test_corr = fold_df["test_Correlation"].mean()

    avg_mse_gap = fold_df["MSE_gap"].mean()
    avg_mae_gap = fold_df["MAE_gap"].mean()
    avg_corr_gap = fold_df["Corr_gap"].mean()

    # Feature count vs performance
    feature_count = dataset_df.shape[1]

    results_summary[experiment_name] = {
        # Headline metrics
        "Feature_Count": feature_count,
        "Aggregate_OOS_MSE": agg_metrics["MSE"],
        "Aggregate_OOS_MAE": agg_metrics["MAE"],
        "Aggregate_OOS_RMSE": agg_metrics["RMSE"],
        "Information_Coefficient": agg_metrics["Correlation"],
        "Aggregate_OOS_R2": agg_metrics["R2"],
        "Aggregate_Directional_Accuracy": agg_metrics["Directional_Accuracy"],
        "Bias": agg_metrics["Bias"],

        # Stability across time
        "Mean_Fold_MSE": stability_test_mse_mean,
        "Std_Fold_MSE": stability_test_mse_std,
        "Mean_Fold_MAE": stability_test_mae_mean,
        "Std_Fold_MAE": stability_test_mae_std,
        "Mean_Fold_Correlation": stability_test_corr_mean,
        "Std_Fold_Correlation": stability_test_corr_std,

        # Overfitting diagnostics
        "Avg_Train_MSE": avg_train_mse,
        "Avg_Test_MSE": avg_test_mse,
        "Avg_MSE_Gap": avg_mse_gap,
        "Avg_Train_MAE": avg_train_mae,
        "Avg_Test_MAE": avg_test_mae,
        "Avg_MAE_Gap": avg_mae_gap,
        "Avg_Train_Correlation": avg_train_corr,
        "Avg_Test_Correlation": avg_test_corr,
        "Avg_Corr_Gap": avg_corr_gap,
    }

    fold_results_by_experiment[experiment_name] = fold_df
    predictions_by_experiment[experiment_name] = {
        "actuals": actuals,
        "preds": preds
    }

    print(
        f"  OOS MSE={agg_metrics['MSE']:.6f} | "
        f"MAE={agg_metrics['MAE']:.6f} | "
        f"IC={agg_metrics['Correlation']:.4f} | "
        f"Features={feature_count}"
    )
    print()

results_df = pd.DataFrame(results_summary).T
results_stock = results_df.reset_index().rename(columns={"index": "Experiment"})

print("\nFinal diagnostic summary:")
display(results_stock)


# ============================================================
# 4. Feature count vs performance tradeoff plot
# ============================================================
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].scatter(results_df["Feature_Count"], results_df["Aggregate_OOS_MSE"], s=80)
for name, row in results_df.iterrows():
    axes[0].annotate(name, (row["Feature_Count"], row["Aggregate_OOS_MSE"]))
axes[0].set_xlabel("Feature Count")
axes[0].set_ylabel("Aggregate OOS MSE")
axes[0].set_title("Feature Count vs OOS MSE")

axes[1].scatter(results_df["Feature_Count"], results_df["Aggregate_OOS_MAE"], s=80)
for name, row in results_df.iterrows():
    axes[1].annotate(name, (row["Feature_Count"], row["Aggregate_OOS_MAE"]))
axes[1].set_xlabel("Feature Count")
axes[1].set_ylabel("Aggregate OOS MAE")
axes[1].set_title("Feature Count vs OOS MAE")

axes[2].scatter(results_df["Feature_Count"], results_df["Information_Coefficient"], s=80)
for name, row in results_df.iterrows():
    axes[2].annotate(name, (row["Feature_Count"], row["Information_Coefficient"]))
axes[2].set_xlabel("Feature Count")
axes[2].set_ylabel("Information Coefficient")
axes[2].set_title("Feature Count vs Correlation")

plt.tight_layout()
plt.show()


# ============================================================
# 5. Performance stability across time
# ============================================================
fig, axes = plt.subplots(3, 1, figsize=(14, 12), sharex=True)

for experiment_name, fold_df in fold_results_by_experiment.items():
    axes[0].plot(fold_df["fold"], fold_df["test_MSE"], label=experiment_name)
    axes[1].plot(fold_df["fold"], fold_df["test_MAE"], label=experiment_name)
    axes[2].plot(fold_df["fold"], fold_df["test_Correlation"], label=experiment_name)

axes[0].set_title("Performance Stability Across Time: Fold Test MSE")
axes[0].set_ylabel("Test MSE")
axes[0].legend()

axes[1].set_title("Performance Stability Across Time: Fold Test MAE")
axes[1].set_ylabel("Test MAE")

axes[2].set_title("Performance Stability Across Time: Fold Test Correlation")
axes[2].set_ylabel("Test Correlation")
axes[2].set_xlabel("Rolling Fold")

plt.tight_layout()
plt.show()


# ============================================================
# 6. Overfitting diagnostics
# ============================================================
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

results_df["Avg_MSE_Gap"].plot(kind="bar", ax=axes[0])
axes[0].set_title("Overfitting Diagnostic: Avg Test MSE - Avg Train MSE")
axes[0].set_ylabel("MSE Gap")
axes[0].tick_params(axis='x', rotation=45)

results_df["Avg_MAE_Gap"].plot(kind="bar", ax=axes[1])
axes[1].set_title("Overfitting Diagnostic: Avg Test MAE - Avg Train MAE")
axes[1].set_ylabel("MAE Gap")
axes[1].tick_params(axis='x', rotation=45)

results_df["Avg_Corr_Gap"].plot(kind="bar", ax=axes[2])
axes[2].set_title("Overfitting Diagnostic: Avg Train Corr - Avg Test Corr")
axes[2].set_ylabel("Correlation Gap")
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Running diagnostic backtests...
#
# Evaluating: Classical_Baseline
#   OOS MSE=0.000633 | MAE=0.019382 | IC=0.0862 | Features=13
#
# Evaluating: Raw13_Baseline
#   OOS MSE=0.000660 | MAE=0.020020 | IC=0.1775 | Features=13
#
# Evaluating: Raw13_Reservoir
#   OOS MSE=0.000620 | MAE=0.019210 | IC=0.1285 | Features=91
#
# Evaluating: Raw13_Patch
#   OOS MSE=0.000718 | MAE=0.020880 | IC=0.0966 | Features=273
#
# Evaluating: Raw13_LQR
#   OOS MSE=0.000611 | MAE=0.018785 | IC=0.1701 | Features=273
#
# Evaluating: Raw13_Patch_LQR
#   OOS MSE=0.000698 | MAE=0.020659 | IC=0.1374 | Features=546
#
#
# Final diagnostic summary:
#            Experiment  Feature_Count  Aggregate_OOS_MSE  Aggregate_OOS_MAE  \
# 0  Classical_Baseline           13.0           0.000633           0.019382
# 1      Raw13_Baseline           13.0           0.000660           0.020020
# 2     Raw13_Reservoir           91.0           0.000620           0.019210
# 3         Raw13_Patch          273.0           0.000718           0.020880
# 4           Raw13_LQR          273.0           0.000611           0.018785
# 5     Raw13_Patch_LQR          546.0           0.000698           0.020659
#
#    Aggregate_OOS_RMSE  Information_Coefficient  Aggregate_OOS_R2  \
# 0            0.025156                 0.086216         -0.036950
# 1            0.025691                 0.177478         -0.081490
# 2            0.024902                 0.128497         -0.016134
# 3            0.026799                 0.096578         -0.176808
# 4            0.024728                 0.170114         -0.001984
# 5            0.026422                 0.137418         -0.143887
#
#    Aggregate_Directional_Accuracy      Bias  Mean_Fold_MSE  ...  \
# 0                          50.400 -0.000053       0.000633  ...
# 1                          56.672 -0.000300       0.000660  ...
# 2                          54.336 -0.000329       0.000620  ...
# 3                          53.312 -0.001141       0.000718  ...
# 4                          55.936  0.000555       0.000611  ...
# 5                          52.704 -0.001008       0.000698  ...
#
#    Std_Fold_Correlation  Avg_Train_MSE  Avg_Test_MSE  Avg_MSE_Gap  \
# 0              0.595159       0.000575      0.000633     0.000058
# 1              0.591729       0.000542      0.000660     0.000118
# 2              0.600229       0.000503      0.000620     0.000117
# 3              0.604416       0.000412      0.000718     0.000307
# 4              0.569260       0.000367      0.000611     0.000245
# 5              0.586282       0.000273      0.000698     0.000425
#
#    Avg_Train_MAE  Avg_Test_MAE  Avg_MAE_Gap  Avg_Train_Correlation  \
# 0       0.018093      0.019382     0.001289               0.256642
# 1       0.017691      0.020020     0.002330               0.337632
# 2       0.016978      0.019210     0.002232               0.470282
# 3       0.015586      0.020880     0.005294               0.594552
# 4       0.014525      0.018785     0.004261               0.703235
# 5       0.012693      0.020659     0.007966               0.778726
#
#    Avg_Test_Correlation  Avg_Corr_Gap
# 0              0.038648      0.217993
# 1              0.120102      0.217530
# 2              0.149992      0.320290
# 3              0.081545      0.513007
# 4              0.083951      0.619284
# 5              0.074109      0.704616
#
# [6 rows x 24 columns]

# %%
results_stock.sort_values("MSE").reset_index(drop=True)

# %% [markdown]
# ---
# ## 11.  Further Reading - Additional Quantum Methods [Experimental]
#
# The methods below are for the purpose of completion of the challenge statement. You are not required to implement these methods as they are for your understanding of the broader landscape.
#
#
# #### Quantum Random Kitchen Sinks
#
# - **What it does**: Approximates a quantum kernel via random features — analogous to classical random Fourier features for the RBF kernel - without building the full N×N kernel matrix.
# - **Key idea**: Instead of computing all O(N²) kernel entries, generate a fixed set of random quantum feature vectors. Their inner products approximate the true quantum kernel. Scales linearly with dataset size rather than quadratically. The reservoir computing approach above is closely related.
# - **Composed of**: Random parameterized circuits → Measurement → Classical feature vector → Linear model
# - **When to use**: When the dataset is too large for full kernel matrix computation but you want the expressiveness of a quantum kernel.
# - **Paper**: Wilson et al., "Quantum Kitchen Sinks: An Algorithm for Machine Learning on Near-Term Quantum Computers," arXiv:1806.08321 (2018)
#
#
#
# #### QAOA-Inspired Feature Maps
#
# - **What it does**: Borrows the QAOA circuit structure — alternating problem and mixer Hamiltonians — as a feature map where the problem Hamiltonian encodes the data.
# - **Key idea**: QAOA circuits carry an inductive bias toward combinatorial structure. Encoding financial features into the problem Hamiltonian gives a feature map with a fundamentally different algebraic form than ZZ or IQP maps, potentially capturing different correlations.
# - **Composed of**: Alternating layers exp(−iγ·C(x)) → exp(−iβ·B), where C(x) is a cost Hamiltonian parameterized by the data
# - **When to use**: Experimental — worth trying if ZZ/IQP maps show no improvement.
# - **Paper**: Farhi, Goldstone & Gutmann, "A Quantum Approximate Optimization Algorithm," arXiv:1411.4028 (2014)
#
#
# #### Quantum Convolutional Neural Network (QCNN)
#
# - **What it does**: Applies the CNN paradigm to quantum circuits — local parameterized gates act on neighboring qubits (convolution), followed by qubit measurement and discard (pooling) to progressively reduce dimensionality.
# - **Key idea**: Each convolutional layer captures local qubit correlations; pooling layers reduce active qubits and suppress barren plateaus. The hierarchical structure mirrors classical CNNs and makes the circuit more noise-resilient.
# - **Composed of**: Convolutional layer (2-qubit parameterized gates) → Pooling (measure and discard half the qubits) → Repeat → Readout
# - **When to use**: When features have sequential or spatial structure — e.g., ordered time-series lags, price features at different lookback horizons.
# - **Paper**: Cong, Choi & Lukin, "Quantum convolutional neural networks," *Nature Physics* 15, 1273–1278 (2019)
#
#
# #### Quantum Transfer Learning
#
# - **What it does**: Uses a pre-trained classical neural network for initial feature extraction, then routes the compressed representation into a variational quantum circuit for final processing.
# - **Key idea**: Classical networks handle high-dimensional, noisy input well. The quantum circuit then operates on a manageable feature count (matching qubit count), potentially capturing correlations the classical network misses. Practically: train a classical autoencoder to reduce raw features to ~5–10 dimensions, then feed those into a VQC.
# - **Composed of**: Classical NN (frozen weights) → Dimensionality reduction layer → VQC → Readout
# - **When to use**: Experimental approach, useful when raw features far exceed the qubits available.
# - **Paper**: Mari et al., "Transfer learning in hybrid classical-quantum neural networks," *Quantum* 4, 340 (2020)

# %% [markdown]
# ---
# **Good luck! Remember: rigorous methodology and honest conclusions matter more than beating the baseline.**
